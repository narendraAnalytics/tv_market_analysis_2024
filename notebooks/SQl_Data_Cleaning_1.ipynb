# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import sqlite3

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/drive/MyDrive/TV_Market_Analysis/data/raw/tv_dataset_cleaned.xls')

# %%
df.head()
# Out:
#                                                Name      Price  \
# 0       OnePlus Y1S 40 inch (101 cm) LED Full HD TV  Rs.18,990
# 1      TCL 32S5403AF 32 inch (81 cm) LED Full HD TV  Rs.13,990
# 2      TCL 32S5400A 32 inch (81 cm) LED HD-Ready TV   Rs.9,990
# 3  Sony BRAVIA KD-65X74L 65 inch (165 cm) LED 4K TV  Rs.74,990
# 4  Sony BRAVIA KD-43X74K 43 inch (109 cm) LED 4K TV  Rs.39,990
#
#                                              Display  \
# 0  40" (101.6 cm), LED\nFull HD, 1920x1080\n60 Hz...
# 1  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...
# 2  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...
# 3  65" (165.1 cm), LED\n4K, 3840x2160\n50 Hz Refr...
# 4  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...
#
#                                       Features  \
# 0            Apps\nVoice Control\nSmart Remote
# 1            Apps\nVoice Control\nSmart Remote
# 2            Apps\nVoice Control\nSmart Remote
# 3            Apps\nVoice Control\nSmart Remote
# 4  Apps and Games\nVoice Control\nSmart Remote
#
#                                     Connectivity  \
# 0  Sound Output: 20 W\n2 USB Ports\n2 HDMI Ports
# 1  Sound Output: 24 W\n1 USB Ports\n2 HDMI Ports
# 2  Sound Output: 24 W\n1 USB Ports\n2 HDMI Ports
# 3  Sound Output: 20 W\n2 USB Ports\n3 HDMI Ports
# 4  Sound Output: 20 W\n2 USB Ports\n3 HDMI Ports
#
#                                               Design
# 0  892 x 512.6 x 85.6 mm\nWeight: 5.1 kg\nColour:...
# 1  715 x 421 x 80 mm\nWeight: 3.44 kg\nColour: Black
# 2  715 x 468 x 80 mm\nWeight: 3.55 kg\nColour: Black
# 3  1463 x 852 x 87 mm\nWeight: 21.4 kg\nColour: B...
# 4   971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black

# %%
# Create an in-memory SQLite database
conn = sqlite3.connect(':memory:')
cursor = conn.cursor()


# Load the Pandas DataFrame into the SQLite database
df.to_sql('tv_data', conn, index=False, if_exists='replace')
# Out:
# 1061

# %%
# Define the query to check for missing values in each column
query = '''
SELECT
    SUM(CASE WHEN Name IS NULL THEN 1 ELSE 0 END) AS Name_missing,
    SUM(CASE WHEN Price IS NULL THEN 1 ELSE 0 END) AS Price_missing,
    SUM(CASE WHEN Display IS NULL THEN 1 ELSE 0 END) AS Display_missing,
    SUM(CASE WHEN Features IS NULL THEN 1 ELSE 0 END) AS Features_missing,
    SUM(CASE WHEN Connectivity IS NULL THEN 1 ELSE 0 END) AS Connectivity_missing,
    SUM(CASE WHEN Design IS NULL THEN 1 ELSE 0 END) AS Design_missing
FROM tv_data
'''

# Execute the query and load the result into a Pandas DataFrame
missing_values = pd.read_sql_query(query, conn)
missing_values
# Out:
#    Name_missing  Price_missing  Display_missing  Features_missing  \
# 0             0              0                0                 0
#
#    Connectivity_missing  Design_missing
# 0                     0               0

# %%
# Define the query to get the data types of each column
query = '''
PRAGMA table_info(tv_data)
'''

# Execute the query and load the result into a Pandas DataFrame
table_info = pd.read_sql_query(query, conn)
table_info
# Out:
#    cid          name  type  notnull dflt_value  pk
# 0    0          Name  TEXT        0       None   0
# 1    1         Price  TEXT        0       None   0
# 2    2       Display  TEXT        0       None   0
# 3    3      Features  TEXT        0       None   0
# 4    4  Connectivity  TEXT        0       None   0
# 5    5        Design  TEXT        0       None   0

# %% [markdown]
# View Basic Statistics of the Price Column

# %%
# Define the query to get basic statistics of the Price column, with rounded average price
query = '''
SELECT
    MIN(CAST(REPLACE(REPLACE(Price, 'Rs.', ''), ',', '') AS INTEGER)) AS min_price,
    MAX(CAST(REPLACE(REPLACE(Price, 'Rs.', ''), ',', '') AS INTEGER)) AS max_price,
    ROUND(AVG(CAST(REPLACE(REPLACE(Price, 'Rs.', ''), ',', '') AS INTEGER)), 2) AS avg_price
FROM tv_data
'''

# Execute the query and load the result into a Pandas DataFrame
price_statistics = pd.read_sql_query(query, conn)
price_statistics
# Out:
#    min_price  max_price  avg_price
# 0       5190    1999990   89344.21

# %% [markdown]
# Standardize the Price Column

# %%
# Convert the Price column to INTEGER while maintaining its position
query = '''
CREATE TABLE tv_data_temp AS
SELECT
    Name,
    CAST(REPLACE(REPLACE(Price, 'Rs.', ''), ',', '') AS INTEGER) AS Price,
    Display,
    Features,
    Connectivity,
    Design
FROM tv_data;

DROP TABLE tv_data;

ALTER TABLE tv_data_temp RENAME TO tv_data;
'''

# Execute the query to convert the Price column to INTEGER
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
updated_table_info = pd.read_sql_query(query, conn)
updated_table_info
# Out:
#    cid          name  type  notnull dflt_value  pk
# 0    0          Name  TEXT        0       None   0
# 1    1         Price   INT        0       None   0
# 2    2       Display  TEXT        0       None   0
# 3    3      Features  TEXT        0       None   0
# 4    4  Connectivity  TEXT        0       None   0
# 5    5        Design  TEXT        0       None   0

# %%
# Define the query to check for duplicates in the dataset
query = '''
SELECT
    Name,
    COUNT(*) as count
FROM
    tv_data
GROUP BY
    Name, Display, Features, Connectivity, Design, Price
HAVING
    COUNT(*) > 1
'''

# Execute the query and load the result into a Pandas DataFrame
duplicates = pd.read_sql_query(query, conn)
duplicates
# Out:
# Empty DataFrame
# Columns: [Name, count]
# Index: []

# %%
# Remove leading and trailing spaces from the Name column
query = '''
UPDATE tv_data
SET Name = TRIM(Name);
'''

# Execute the query to remove leading and trailing spaces
cursor.execute(query)
conn.commit()

# Verify the changes
query = '''
SELECT DISTINCT Name
FROM tv_data
LIMIT 5
'''

# Execute the query and load the result into a Pandas DataFrame
cleaned_names = pd.read_sql_query(query, conn)
cleaned_names
# Out:
#                                                Name
# 0       OnePlus Y1S 40 inch (101 cm) LED Full HD TV
# 1      TCL 32S5403AF 32 inch (81 cm) LED Full HD TV
# 2      TCL 32S5400A 32 inch (81 cm) LED HD-Ready TV
# 3  Sony BRAVIA KD-65X74L 65 inch (165 cm) LED 4K TV
# 4  Sony BRAVIA KD-43X74K 43 inch (109 cm) LED 4K TV

# %%
# Convert the Name column to lower case
query = '''
UPDATE tv_data
SET Name = LOWER(Name);
'''

# Execute the query to convert to lower case
cursor.execute(query)
conn.commit()

# Verify the changes
query = '''
SELECT DISTINCT Name
FROM tv_data
LIMIT 5
'''

# Execute the query and load the result into a Pandas DataFrame
lower_case_names = pd.read_sql_query(query, conn)
lower_case_names
# Out:
#                                                Name
# 0       oneplus y1s 40 inch (101 cm) led full hd tv
# 1      tcl 32s5403af 32 inch (81 cm) led full hd tv
# 2      tcl 32s5400a 32 inch (81 cm) led hd-ready tv
# 3  sony bravia kd-65x74l 65 inch (165 cm) led 4k tv
# 4  sony bravia kd-43x74k 43 inch (109 cm) led 4k tv

# %%
# Extract the Brand column and place it after the Name column
# Add the new Brand column
query = '''
ALTER TABLE tv_data ADD COLUMN Brand TEXT;
'''

# Execute the query to add the Brand column
cursor.execute(query)
conn.commit()

# Update the Brand column by extracting the first word from the Name column
query = '''
UPDATE tv_data
SET Brand = SUBSTR(Name, 1, INSTR(Name, ' ') - 1);
'''

# Execute the query to populate the Brand column
cursor.execute(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
updated_table_info_with_brand = pd.read_sql_query(query, conn)
updated_table_info_with_brand
# Out:
#    cid          name  type  notnull dflt_value  pk
# 0    0          Name  TEXT        0       None   0
# 1    1         Price   INT        0       None   0
# 2    2       Display  TEXT        0       None   0
# 3    3      Features  TEXT        0       None   0
# 4    4  Connectivity  TEXT        0       None   0
# 5    5        Design  TEXT        0       None   0
# 6    6         Brand  TEXT        0       None   0

# %%
# Create a temporary table with the desired column order
query = '''
CREATE TABLE tv_data_temp AS
SELECT
    Name,
    SUBSTR(Name, 1, INSTR(Name, ' ') - 1) AS Brand,
    Price,
    Display,
    Features,
    Connectivity,
    Design
FROM tv_data;

-- Drop the original table
DROP TABLE tv_data;

-- Rename the temporary table to the original table name
ALTER TABLE tv_data_temp RENAME TO tv_data;
'''

# Execute the queries to reorder columns
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
updated_table_info_reordered = pd.read_sql_query(query, conn)
updated_table_info_reordered
# Out:
#    cid          name  type  notnull dflt_value  pk
# 0    0          Name  TEXT        0       None   0
# 1    1         Brand              0       None   0
# 2    2         Price   INT        0       None   0
# 3    3       Display  TEXT        0       None   0
# 4    4      Features  TEXT        0       None   0
# 5    5  Connectivity  TEXT        0       None   0
# 6    6        Design  TEXT        0       None   0

# %%
# Change the Brand column type to TEXT
query = '''
ALTER TABLE tv_data
RENAME TO tv_data_temp;

CREATE TABLE tv_data (
    Name TEXT,
    Brand TEXT,
    Price INTEGER,
    Display TEXT,
    Features TEXT,
    Connectivity TEXT,
    Design TEXT
);

INSERT INTO tv_data (Name, Brand, Price, Display, Features, Connectivity, Design)
SELECT Name, Brand, Price, Display, Features, Connectivity, Design
FROM tv_data_temp;

DROP TABLE tv_data_temp;
'''

# Execute the query to change the Brand column type to TEXT
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
updated_table_info_with_text_brand = pd.read_sql_query(query, conn)
updated_table_info_with_text_brand
# Out:
#    cid          name     type  notnull dflt_value  pk
# 0    0          Name     TEXT        0       None   0
# 1    1         Brand     TEXT        0       None   0
# 2    2         Price  INTEGER        0       None   0
# 3    3       Display     TEXT        0       None   0
# 4    4      Features     TEXT        0       None   0
# 5    5  Connectivity     TEXT        0       None   0
# 6    6        Design     TEXT        0       None   0

# %% [markdown]
#  Extraction of the Model Column

# %%
# Create a temporary table with the desired column order and extract the model information
query = '''
CREATE TABLE tv_data_temp AS
SELECT
    Name,
    Brand,
    TRIM(SUBSTR(Name, LENGTH(Brand) + 2, INSTR(Name, ' inch') - LENGTH(Brand) - 3)) AS Model,
    Price,
    Display,
    Features,
    Connectivity,
    Design
FROM tv_data;

-- Drop the original table
DROP TABLE tv_data;

-- Rename the temporary table to the original table name
ALTER TABLE tv_data_temp RENAME TO tv_data;
'''

# Execute the queries to reorder columns and extract the model information
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
updated_table_info_with_model = pd.read_sql_query(query, conn)
updated_table_info_with_model
# Out:
#    cid          name  type  notnull dflt_value  pk
# 0    0          Name  TEXT        0       None   0
# 1    1         Brand  TEXT        0       None   0
# 2    2         Model              0       None   0
# 3    3         Price   INT        0       None   0
# 4    4       Display  TEXT        0       None   0
# 5    5      Features  TEXT        0       None   0
# 6    6  Connectivity  TEXT        0       None   0
# 7    7        Design  TEXT        0       None   0

# %%
# Create a temporary table with the correct column types and desired column order
query = '''
CREATE TABLE tv_data_temp (
    Name TEXT,
    Brand TEXT,
    Model TEXT,
    Price INTEGER,
    Display TEXT,
    Features TEXT,
    Connectivity TEXT,
    Design TEXT
);

-- Copy data from the current table to the temporary table
INSERT INTO tv_data_temp (Name, Brand, Model, Price, Display, Features, Connectivity, Design)
SELECT Name, Brand, Model, Price, Display, Features, Connectivity, Design
FROM tv_data;

-- Drop the original table
DROP TABLE tv_data;

-- Rename the temporary table to the original table name
ALTER TABLE tv_data_temp RENAME TO tv_data;
'''

# Execute the queries to ensure correct column types and reorder columns
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
final_table_info = pd.read_sql_query(query, conn)
final_table_info
# Out:
#    cid          name     type  notnull dflt_value  pk
# 0    0          Name     TEXT        0       None   0
# 1    1         Brand     TEXT        0       None   0
# 2    2         Model     TEXT        0       None   0
# 3    3         Price  INTEGER        0       None   0
# 4    4       Display     TEXT        0       None   0
# 5    5      Features     TEXT        0       None   0
# 6    6  Connectivity     TEXT        0       None   0
# 7    7        Design     TEXT        0       None   0

# %%
# Create a temporary table with the desired column order and extract the screen size (in inches)
query = '''
CREATE TABLE tv_data_temp AS
SELECT
    Name,
    Brand,
    Model,
    CAST(SUBSTR(Name, INSTR(Name, 'inch') - 3, 2) AS INTEGER) AS Inches,
    Price,
    Display,
    Features,
    Connectivity,
    Design
FROM tv_data;

-- Drop the original table
DROP TABLE tv_data;

-- Rename the temporary table to the original table name
ALTER TABLE tv_data_temp RENAME TO tv_data;
'''

# Execute the queries to reorder columns and extract the screen size (in inches)
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
updated_table_info_with_inches = pd.read_sql_query(query, conn)
updated_table_info_with_inches
# Out:
#    cid          name  type  notnull dflt_value  pk
# 0    0          Name  TEXT        0       None   0
# 1    1         Brand  TEXT        0       None   0
# 2    2         Model  TEXT        0       None   0
# 3    3        Inches   INT        0       None   0
# 4    4         Price   INT        0       None   0
# 5    5       Display  TEXT        0       None   0
# 6    6      Features  TEXT        0       None   0
# 7    7  Connectivity  TEXT        0       None   0
# 8    8        Design  TEXT        0       None   0

# %%
# Create a temporary table with the desired column order and correct column types
query = '''
CREATE TABLE tv_data_temp (
    Name TEXT,
    Brand TEXT,
    Model TEXT,
    Inches INTEGER,
    Price INTEGER,
    Resolution TEXT,
    Display TEXT,
    Features TEXT,
    Connectivity TEXT,
    Design TEXT
);

-- Copy data from the current table to the temporary table
INSERT INTO tv_data_temp (Name, Brand, Model, Inches, Price, Resolution, Display, Features, Connectivity, Design)
SELECT
    Name,
    Brand,
    Model,
    Inches,
    Price,
    TRIM(SUBSTR(Name, INSTR(Name, ')') + 2)) AS Resolution,
    Display,
    Features,
    Connectivity,
    Design
FROM tv_data;

-- Drop the original table
DROP TABLE tv_data;

-- Rename the temporary table to the original table name
ALTER TABLE tv_data_temp RENAME TO tv_data;
'''

# Execute the queries to ensure correct column types and reorder columns
cursor.executescript(query)
conn.commit()

# Verify the changes
query = '''
PRAGMA table_info(tv_data);
'''

# Execute the query and load the result into a Pandas DataFrame
final_table_info_with_resolution = pd.read_sql_query(query, conn)
final_table_info_with_resolution
# Out:
#    cid          name     type  notnull dflt_value  pk
# 0    0          Name     TEXT        0       None   0
# 1    1         Brand     TEXT        0       None   0
# 2    2         Model     TEXT        0       None   0
# 3    3        Inches  INTEGER        0       None   0
# 4    4         Price  INTEGER        0       None   0
# 5    5    Resolution     TEXT        0       None   0
# 6    6       Display     TEXT        0       None   0
# 7    7      Features     TEXT        0       None   0
# 8    8  Connectivity     TEXT        0       None   0
# 9    9        Design     TEXT        0       None   0

# %%
# Query to select the first 5 rows of the updated table
query = '''
SELECT *
FROM tv_data
LIMIT 5
'''

# Execute the query and load the result into a Pandas DataFrame
first_five_rows_updated = pd.read_sql_query(query, conn)
first_five_rows_updated
# Out:
#                                                Name    Brand  \
# 0       oneplus y1s 40 inch (101 cm) led full hd tv  oneplus
# 1      tcl 32s5403af 32 inch (81 cm) led full hd tv      tcl
# 2      tcl 32s5400a 32 inch (81 cm) led hd-ready tv      tcl
# 3  sony bravia kd-65x74l 65 inch (165 cm) led 4k tv     sony
# 4  sony bravia kd-43x74k 43 inch (109 cm) led 4k tv     sony
#
#                 Model  Inches  Price      DisplayType  \
# 0               y1s 4      40  18990   led full hd tv
# 1         32s5403af 3      32  13990   led full hd tv
# 2          32s5400a 3      32   9990  led hd-ready tv
# 3  bravia kd-65x74l 6      65  74990        led 4k tv
# 4  bravia kd-43x74k 4      43  39990        led 4k tv
#
#                                              Display Resolution  \
# 0  40" (101.6 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080
# 1  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080
# 2  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768
# 3  65" (165.1 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160
# 4  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
#
#                                       Features  \
# 0            Apps\nVoice Control\nSmart Remote
# 1            Apps\nVoice Control\nSmart Remote
# 2            Apps\nVoice Control\nSmart Remote
# 3            Apps\nVoice Control\nSmart Remote
# 4  Apps and Games\nVoice Control\nSmart Remote
#
#                                     Connectivity  \
# 0  Sound Output: 20 W\n2 USB Ports\n2 HDMI Ports
# 1  Sound Output: 24 W\n1 USB Ports\n2 HDMI Ports
# 2  Sound Output: 24 W\n1 USB Ports\n2 HDMI Ports
# 3  Sound Output: 20 W\n2 USB Ports\n3 HDMI Ports
# 4  Sound Output: 20 W\n2 USB Ports\n3 HDMI Ports
#
#                                               Design
# 0  892 x 512.6 x 85.6 mm\nWeight: 5.1 kg\nColour:...
# 1  715 x 421 x 80 mm\nWeight: 3.44 kg\nColour: Black
# 2  715 x 468 x 80 mm\nWeight: 3.55 kg\nColour: Black
# 3  1463 x 852 x 87 mm\nWeight: 21.4 kg\nColour: B...
# 4   971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black

# %%
# Get the list of columns and their data types
query1 = "PRAGMA table_info(tv_data)"
columns_info = pd.read_sql(query1, conn)
columns_info
# Out:
#     cid          name     type  notnull dflt_value  pk
# 0     0          Name     TEXT        0       None   0
# 1     1         Brand     TEXT        0       None   0
# 2     2         Model     TEXT        0       None   0
# 3     3        Inches  INTEGER        0       None   0
# 4     4         Price  INTEGER        0       None   0
# 5     5   DisplayType     TEXT        0       None   0
# 6     6       Display     TEXT        0       None   0
# 7     7    Resolution     TEXT        0       None   0
# 8     8      Features     TEXT        0       None   0
# 9     9  Connectivity     TEXT        0       None   0
# 10   10        Design     TEXT        0       None   0

# %%
# Rename the existing Resolution column to DisplayType
rename_column_query = "ALTER TABLE tv_data RENAME COLUMN Resolution TO DisplayType"
cursor.execute(rename_column_query)

# Confirm the column rename
query_columns_info = "PRAGMA table_info(tv_data)"
updated_columns_info = pd.read_sql(query_columns_info, conn)



updated_columns_info
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-106-5da92044fe72> in <cell line: 3>()
#       1 # Rename the existing Resolution column to DisplayType
#       2 rename_column_query = "ALTER TABLE tv_data RENAME COLUMN Resolution TO DisplayType"
# ----> 3 cursor.execute(rename_column_query)
#       4
#       5 # Confirm the column rename
#
# OperationalError: error in table tv_data after rename: duplicate column name: DisplayType

# %%
# Add the ActualResolution column
cursor.execute("ALTER TABLE tv_data ADD COLUMN ActualResolution TEXT")

# Extract the resolution using a general pattern
extract_resolution_query = """
UPDATE tv_data
SET ActualResolution = TRIM(SUBSTR(Display, INSTR(Display, 'x')-4, 9))
WHERE INSTR(Display, 'x') > 0;
"""
cursor.execute(extract_resolution_query)

# Confirm the extraction by displaying the first 5 rows of the updated table
query_actual_resolution = "SELECT Display, ActualResolution FROM tv_data LIMIT 5"
actual_resolution_first_5_rows = pd.read_sql(query_actual_resolution, conn)


actual_resolution_first_5_rows
# Out:
#                                              Display ActualResolution
# 0  40" (101.6 cm), LED\nFull HD, 1920x1080\n60 Hz...        1920x1080
# 1  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...        1920x1080
# 2  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...       1366x768\n
# 3  65" (165.1 cm), LED\n4K, 3840x2160\n50 Hz Refr...        3840x2160
# 4  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...        3840x2160

# %%
# Clean the ActualResolution column
clean_actual_resolution_query = """
UPDATE tv_data
SET ActualResolution = TRIM(REPLACE(ActualResolution, '\n', ''));
"""
cursor.execute(clean_actual_resolution_query)

# Confirm the cleaning by displaying the first 5 rows of the updated table
query_cleaned_actual_resolution = "SELECT Display, ActualResolution FROM tv_data LIMIT 5"
cleaned_actual_resolution_first_5_rows = pd.read_sql(query_cleaned_actual_resolution, conn)

cleaned_actual_resolution_first_5_rows
# Out:
#                                              Display ActualResolution
# 0  40" (101.6 cm), LED\nFull HD, 1920x1080\n60 Hz...        1920x1080
# 1  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...        1920x1080
# 2  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...         1366x768
# 3  65" (165.1 cm), LED\n4K, 3840x2160\n50 Hz Refr...        3840x2160
# 4  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...        3840x2160

# %%
# Get the list of columns and their data types
query = "PRAGMA table_info(tv_data)"
columns_info = pd.read_sql(query, conn)
columns_info
# Out:
#     cid              name     type  notnull dflt_value  pk
# 0     0              Name     TEXT        0       None   0
# 1     1             Brand     TEXT        0       None   0
# 2     2             Model     TEXT        0       None   0
# 3     3            Inches  INTEGER        0       None   0
# 4     4             Price  INTEGER        0       None   0
# 5     5       DisplayType     TEXT        0       None   0
# 6     6           Display     TEXT        0       None   0
# 7     7        Resolution     TEXT        0       None   0
# 8     8          Features     TEXT        0       None   0
# 9     9      Connectivity     TEXT        0       None   0
# 10   10            Design     TEXT        0       None   0
# 11   11  ActualResolution     TEXT        0       None   0

# %%
# Rename the ActualResolution column to Resolution and place it after the Display column
# Since SQLite doesn't support direct column reordering, we'll create a new table with the desired schema and copy the data over.

# Create a new table with the desired column order
create_new_table_query = """
CREATE TABLE tv_data_new (
    Name TEXT,
    Brand TEXT,
    Model TEXT,
    Inches INTEGER,
    Price INTEGER,
    DisplayType TEXT,
    Display TEXT,
    Resolution TEXT,
    Features TEXT,
    Connectivity TEXT,
    Design TEXT
);
"""
cursor.execute(create_new_table_query)

# Copy the data from the old table to the new table
copy_data_query = """
INSERT INTO tv_data_new (Name, Brand, Model, Inches, Price, DisplayType, Display, Resolution, Features, Connectivity, Design)
SELECT Name, Brand, Model, Inches, Price, DisplayType, Display, ActualResolution, Features, Connectivity, Design
FROM tv_data;
"""
cursor.execute(copy_data_query)

# Drop the old table
drop_old_table_query = "DROP TABLE tv_data"
cursor.execute(drop_old_table_query)

# Rename the new table to the original table name
rename_new_table_query = "ALTER TABLE tv_data_new RENAME TO tv_data"
cursor.execute(rename_new_table_query)

# Confirm the column rename and reordering
query_columns_info_final = "PRAGMA table_info(tv_data)"
final_columns_info = pd.read_sql(query_columns_info_final, conn)


final_columns_info
# Out:
#     cid          name     type  notnull dflt_value  pk
# 0     0          Name     TEXT        0       None   0
# 1     1         Brand     TEXT        0       None   0
# 2     2         Model     TEXT        0       None   0
# 3     3        Inches  INTEGER        0       None   0
# 4     4         Price  INTEGER        0       None   0
# 5     5   DisplayType     TEXT        0       None   0
# 6     6       Display     TEXT        0       None   0
# 7     7    Resolution     TEXT        0       None   0
# 8     8      Features     TEXT        0       None   0
# 9     9  Connectivity     TEXT        0       None   0
# 10   10        Design     TEXT        0       None   0

# %%
# Query to get 5 random rows of the dataset
query_random_5_rows = "SELECT * FROM tv_data ORDER BY RANDOM() LIMIT 5"
random_5_rows = pd.read_sql(query_random_5_rows, conn)

random_5_rows
# Out:
#                                                 Name    Brand  \
# 0      jvc lt-65nq7115cgx 65 inch (165 cm) led 4k tv      jvc
# 1              tcl 75p635 75 inch (190 cm) led 4k tv      tcl
# 2  samsung qa75qn90dau 75 inch (190 cm) neo qled ...  samsung
# 3      tcl 55c755 55 inch (139 cm) qd-mini led 4k tv      tcl
# 4          lg 55uq8040psb 55 inch (139 cm) led 4k tv       lg
#
#               Model  Inches   Price        DisplayType  \
# 0  lt-65nq7115cgx 6      65   67490          led 4k tv
# 1          75p635 7      75   69990          led 4k tv
# 2     qa75qn90dau 7      75  449990     neo qled 4k tv
# 3          55c755 5      55   79990  qd-mini led 4k tv
# 4     55uq8040psb 5      55   50999          led 4k tv
#
#                                              Display Resolution  \
# 0  65" (165.1 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160
# 1  75" (190.5 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160
# 2  75" (190.5 cm), Neo QLED\n4K, 3840x2160\n100 H...  3840x2160
# 3  55" (139.7 cm), QD-Mini LED\n4K, 3840x2160\n14...  3840x2160
# 4  55" (139.7 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160
#
#                                      Features  \
# 0                         Apps\nVoice Control
# 1                          Apps\nSmart Remote
# 2  Apps and Games\nWeb Browser\nVoice Control
# 3           Apps\nVoice Control\nSmart Remote
# 4                                        Apps
#
#                                     Connectivity  \
# 0  Sound Output: 24 W\n2 USB Ports\n4 HDMI Ports
# 1  Sound Output: 20 W\n2 USB Ports\n3 HDMI Ports
# 2  Sound Output: 60 W\n2 USB Ports\n4 HDMI Ports
# 3  Sound Output: 30 W\n2 USB Ports\n4 HDMI Ports
# 4               Sound Output: 20 W\n3 HDMI Ports
#
#                                               Design
# 0                                      Colour: Black
# 1  1446 x 833 x 81 mm\nWeight: 10.5 kg\nColour: B...
# 2  16.7 x 957.4 x 27.7 mm\nWeight: 34.1 kg\nColou...
# 3   1224 x 710 x 70 mm\nWeight: 13 kg\nColour: Black
# 4  1235 x 715 x 57.5 mm\nWeight: 14 kg\nColour: B...

# %%
# Query to get the value counts of the Features column
query_features_value_counts = "SELECT Features, COUNT(*) as count FROM tv_data GROUP BY Features ORDER BY count DESC"
features_value_counts = pd.read_sql(query_features_value_counts, conn)

features_value_counts
# Out:
#                                            Features  count
# 0        Apps and Games\nWeb Browser\nVoice Control    190
# 1                 Apps\nVoice Control\nSmart Remote    147
# 2                                              Apps    128
# 3                                              None     81
# 4                               Apps\nVoice Control     67
# 5             Apps and Games\nWeb Browser\nFacebook     55
# 6                                Apps\nSmart Remote     55
# 7            and Games\nVoice Control\nSmart Remote     35
# 8             and Games\nWeb Browser\nVoice Control     31
# 9       Apps and Games\nVoice Control\nSmart Remote     31
# 10                 Apps\nWeb Browser\nVoice Control     29
# 11                    Apps and Games\nVoice Control     23
# 12                                    Voice Control     18
# 13                      Voice Control\nSmart Remote     15
# 14          Apps and Games\nVoice Control\nFacebook     15
# 15                         and Games\nVoice Control     14
# 16                                Apps\nWeb Browser     13
# 17                                        and Games     11
# 18                                     Smart Remote      8
# 19                  Apps\nWeb Browser\nSmart Remote      8
# 20   Apps and Games\nGesture Control\nVoice Control      7
# 21                                   Apps and Games      6
# 22         and Games\nWeb Browser\nSkype Compatible      5
# 23     Web Browser\nVoice Control\nSkype Compatible      5
# 24                     Apps and Games\nSmart Remote      5
# 25              Apps\nWeb Browser\nSkype Compatible      5
# 26                      Apps\nWeb Browser\nFacebook      5
# 27                          and Games\nSmart Remote      4
# 28                      and Games\nSkype Compatible      4
# 29                                      Web Browser      4
# 30        Apps and Games\nWeb Browser\nSmart Remote      4
# 31            Apps\nVoice Control\nSkype Compatible      4
# 32                      Apps and Games\nWeb Browser      3
# 33             and Games\nWeb Browser\nSmart Remote      2
# 34                 and Games\nWeb Browser\nFacebook      2
# 35                           and Games\nWeb Browser      2
# 36         Web Browser\nVoice Control\nSmart Remote      2
# 37      Web Browser\nSkype Compatible\nSmart Remote      2
# 38                    Web Browser\nSkype Compatible      2
# 39  Apps and Games\nVoice Control\nSkype Compatible      2
# 40                         Apps and Games\nFacebook      2
# 41          and Games\nWeb Browser\nGesture Control      1
# 42                              and Games\nFacebook      1
# 43    Voice Control\nSkype Compatible\nSmart Remote      1
# 44                  Voice Control\nSkype Compatible      1
# 45                                 Skype Compatible      1
# 46    Apps and Games\nWeb Browser\nSkype Compatible      1
# 47   Apps and Games\nSkype Compatible\nSmart Remote      1
# 48           Apps and Games\nFacebook\nSmart Remote      1
# 49                        2 USB Ports\n3 HDMI Ports      1
# 50                        1 USB Ports\n2 HDMI Ports      1

# %%
# Update the rows with NaN in the Features column where the text starts with "Sound Output"
update_features_nan_query = """
UPDATE tv_data
SET Features = NULL
WHERE Features LIKE 'Sound Output%';
"""
cursor.execute(update_features_nan_query)

# Confirm the update by selecting the rows where Features is NULL
query_confirm_update = """
SELECT *
FROM tv_data
WHERE Features IS NULL;
"""
features_nan_confirm = pd.read_sql(query_confirm_update, conn)


features_nan_confirm
# Out:
#                                                  Name      Brand  \
# 0    marq 32hdndqee1b 32 inch (81 cm) led hd-ready tv       marq
# 1   dyanora dy-ld32h1n 32 inch (81 cm) led hd-read...    dyanora
# 2   beethosol ledatbg32hdek 32 inch (81 cm) led hd...  beethosol
# 3      sansui jsw65asuhdff 65 inch (165 cm) led 4k tv     sansui
# 4       adsun a-3200n 32 inch (81 cm) led hd-ready tv      adsun
# 5     adsun a-3200f/n 32 inch (81 cm) led hd-ready tv      adsun
# 6   beethosol ledatvbg2483hd17-tp 24 inch (60 cm) ...  beethosol
# 7   samsung ua32t4010ar 32 inch (81 cm) led hd-rea...    samsung
# 8      samsung qa43q60cak 43 inch (109 cm) qled 4k tv    samsung
# 9      samsung ua50cu8000k 50 inch (127 cm) led 4k tv    samsung
# 10   thomson 24tm2490 24 inch (60 cm) led hd-ready tv    thomson
# 11   thomson 32tm3290 32 inch (81 cm) led hd-ready tv    thomson
# 12      adsun a-2400n 24 inch (60 cm) led hd-ready tv      adsun
# 13     samsung ua55cu8570u 55 inch (139 cm) led 4k tv    samsung
# 14  dyanora dy-ld24h0n 24 inch (60 cm) led hd-read...    dyanora
# 15  beethosol atvbg24hdek 24 inch (60 cm) led hd-r...  beethosol
# 16   marq 24hdndqppab 24 inch (60 cm) led hd-ready tv       marq
# 17  marq 43fhdcdqee1b 43 inch (109 cm) led full hd tv       marq
# 18   sony bravia kd-43x75l 43 inch (109 cm) led 4k tv       sony
# 19  blaupunkt 24sigma707 24 inch (60 cm) led hd-re...  blaupunkt
# 20   sony bravia kd-50x75l 50 inch (127 cm) led 4k tv       sony
# 21    xelectron 24stv 24 inch (60 cm) led hd-ready tv  xelectron
# 22    xelectron 32stv 32 inch (81 cm) led hd-ready tv  xelectron
# 23   sansui jsy24nshd 24 inch (60 cm) led hd-ready tv     sansui
# 24  samsung ua32t4050ar 32 inch (81 cm) led hd-rea...    samsung
# 25  power guard pg32n 32 inch (81 cm) led hd-ready tv      power
# 26   sony bravia xr-75x90l 75 inch (190 cm) led 4k tv       sony
# 27  samsung ua32n4000ak 32 inch (81 cm) led hd-rea...    samsung
# 28  samsung ua32n4003ar 32 inch (81 cm) led hd-rea...    samsung
# 29    samsung qa75qn90cak 75 inch (190 cm) qled 4k tv    samsung
# 30  zebronics zeb-32p1 32 inch (81 cm) led hd-read...  zebronics
# 31         lg 24lp520v 24 inch (60 cm) led full hd tv         lg
# 32      cellecor 24cs 24 inch (60 cm) led hd-ready tv   cellecor
# 33  t-series tx-24bis 24 inch (60 cm) led hd-ready tv   t-series
# 34     samsung qa55s90cak 55 inch (139 cm) oled 4k tv    samsung
# 35          lg 43ur7790psa 43 inch (109 cm) led 4k tv         lg
# 36         haier le43a9000 43 inch (109 cm) lcd 4k tv      haier
# 37  aiwa magnifiq av32hdx1 32 inch (81 cm) led ful...       aiwa
# 38  t-series 32two 300h 32 inch (81 cm) led hd-rea...   t-series
# 39     innoq 24e-npro 24 inch (60 cm) led hd-ready tv      innoq
# 40       bpl 32-d4301 32 inch (81 cm) led hd-ready tv        bpl
# 41      bpl 43f-e2300 43 inch (109 cm) led full hd tv        bpl
# 42           bpl 55u-d5310 55 inch (139 cm) led 4k tv        bpl
# 43  dyanora dy-ld24h1n 24 inch (60 cm) led hd-read...    dyanora
# 44           onida 43uig-r 43 inch (109 cm) led 4k tv      onida
# 45  croma crel032hbc024602 32 inch (81 cm) led hd-...      croma
# 46  aiwa magnifiq as55uhdx1-gtv 55 inch (139 cm) l...       aiwa
# 47  croma crel032hbd307601 32 inch (81 cm) led hd-...      croma
# 48  panasonic th-43ms680dx 43 inch (109 cm) led fu...  panasonic
# 49  panasonic th-43ms550dx 43 inch (109 cm) led fu...  panasonic
# 50   t-series ts80c-a 32 inch (81 cm) led hd-ready tv   t-series
# 51  t-series 43two400f 43 inch (109 cm) led full h...   t-series
# 52         detel di65bsakb 65 inch (165 cm) led 4k tv      detel
# 53         lg 55qned80sra 55 inch (139 cm) qned 4k tv         lg
# 54           aiwa a43fhdx1 43 inch (109 cm) led 4k tv       aiwa
# 55          lg 70ur8050psb 70 inch (177 cm) led 4k tv         lg
# 56          lg 75ur8050psb 75 inch (190 cm) led 4k tv         lg
# 57     samsung qa65q70cak 65 inch (165 cm) qled 4k tv    samsung
# 58     samsung ua85cu8000k 85 inch (215 cm) led 4k tv    samsung
# 59  aiwa magnifiq a32hdx1 32 inch (81 cm) led hd-r...       aiwa
# 60      cellecor e32n 32 inch (81 cm) led hd-ready tv   cellecor
# 61     samsung ua75cu7700k 75 inch (190 cm) led 4k tv    samsung
# 62       haier le32a7 32 inch (81 cm) led hd-ready tv      haier
# 63    haier le32a9000 32 inch (81 cm) led hd-ready tv      haier
# 64  akai aklt24n-d53w 24 inch (60 cm) led hd-ready tv       akai
# 65     samsung ua55cu7700k 55 inch (139 cm) led 4k tv    samsung
# 66  croma crel065uga024601 65 inch (165 cm) qled 4...      croma
# 67     samsung ua65cu8000k 65 inch (165 cm) led 4k tv    samsung
# 68     samsung ua55cu8000k 55 inch (139 cm) led 4k tv    samsung
# 69  croma crel024hbb024602 24 inch (60 cm) led hd-...      croma
# 70         tcl 32s5201 32 inch (81 cm) led full hd tv        tcl
# 71  samsung ua32t4360 32 inch (81 cm) led hd-ready tv    samsung
# 72  samsung ua32t4110ar 32 inch (81 cm) led hd-rea...    samsung
# 73       itel a2410ie 24 inch (60 cm) led hd-ready tv       itel
# 74  panasonic th-42js650dx 42 inch (106 cm) led fu...  panasonic
# 75          lg 86nano75sqa 86 inch (218 cm) led 4k tv         lg
# 76          lg 55nano75sqa 55 inch (139 cm) led 4k tv         lg
# 77  panasonic th-32j200dx 32 inch (81 cm) led hd-r...  panasonic
# 78     lloyd 32hb250c 32 inch (81 cm) led hd-ready tv      lloyd
# 79   sansui jsw32nshd 32 inch (81 cm) led hd-ready tv     sansui
# 80  sharp lc-32le185m 32 inch (81 cm) led hd-ready tv      sharp
#
#                        Model  Inches   Price      DisplayType  \
# 0              32hdndqee1b 3      32    7449  led hd-ready tv
# 1               dy-ld32h1n 3      32    7999  led hd-ready tv
# 2            ledatbg32hdek 3      32    7399  led hd-ready tv
# 3             jsw65asuhdff 6      65   51999        led 4k tv
# 4                  a-3200n 3      32    6789  led hd-ready tv
# 5                a-3200f/n 3      32    7200  led hd-ready tv
# 6      ledatvbg2483hd17-tp 2      24    5499  led hd-ready tv
# 7              ua32t4010ar 3      32   16290  led hd-ready tv
# 8               qa43q60cak 4      43   62990       qled 4k tv
# 9              ua50cu8000k 5      50   55290        led 4k tv
# 10                24tm2490 2      24    6299  led hd-ready tv
# 11                32tm3290 3      32    7999  led hd-ready tv
# 12                 a-2400n 2      24    5650  led hd-ready tv
# 13             ua55cu8570u 5      55   71990        led 4k tv
# 14              dy-ld24h0n 2      24    5999  led hd-ready tv
# 15             atvbg24hdek 2      24    5299  led hd-ready tv
# 16             24hdndqppab 2      24    5499  led hd-ready tv
# 17            43fhdcdqee1b 4      43   15249   led full hd tv
# 18        bravia kd-43x75l 4      43   46540        led 4k tv
# 19              24sigma707 2      24    6499  led hd-ready tv
# 20        bravia kd-50x75l 5      50   57940        led 4k tv
# 21                   24stv 2      24    5999  led hd-ready tv
# 22                   32stv 3      32    7499  led hd-ready tv
# 23               jsy24nshd 2      24    7999  led hd-ready tv
# 24             ua32t4050ar 3      32   17290  led hd-ready tv
# 25             guard pg32n 3      32    7499  led hd-ready tv
# 26        bravia xr-75x90l 7      75  251740        led 4k tv
# 27             ua32n4000ak 3      32   13633  led hd-ready tv
# 28             ua32n4003ar 3      32   13633  led hd-ready tv
# 29             qa75qn90cak 7      75  429990       qled 4k tv
# 30                zeb-32p1 3      32   10999  led hd-ready tv
# 31                24lp520v 2      24   13835   led full hd tv
# 32                    24cs 2      24    6444  led hd-ready tv
# 33                tx-24bis 2      24    6990  led hd-ready tv
# 34              qa55s90cak 5      55  144990       oled 4k tv
# 35             43ur7790psa 4      43   42990        led 4k tv
# 36               le43a9000 4      43   30990        lcd 4k tv
# 37       magnifiq av32hdx1 3      32   10790   led full hd tv
# 38              32two 300h 3      32   11990  led hd-ready tv
# 39                24e-npro 2      24    5490  led hd-ready tv
# 40                32-d4301 3      32   13490  led hd-ready tv
# 41               43f-e2300 4      43   20990   led full hd tv
# 42               55u-d5310 5      55   38990        led 4k tv
# 43              dy-ld24h1n 2      24    5999  led hd-ready tv
# 44                 43uig-r 4      43   27159        led 4k tv
# 45        crel032hbc024602 3      32    7990  led hd-ready tv
# 46  magnifiq as55uhdx1-gtv 5      55   37890        led 4k tv
# 47        crel032hbd307601 3      32    7590  led hd-ready tv
# 48            th-43ms680dx 4      43   32490   led full hd tv
# 49            th-43ms550dx 4      43   25590   led full hd tv
# 50                 ts80c-a 3      32   10990  led hd-ready tv
# 51               43two400f 4      43   27990   led full hd tv
# 52               di65bsakb 6      65  119999        led 4k tv
# 53             55qned80sra 5      55   75990       qned 4k tv
# 54                a43fhdx1 4      43   20990        led 4k tv
# 55             70ur8050psb 7      70   88990        led 4k tv
# 56             75ur8050psb 7      75  127990        led 4k tv
# 57              qa65q70cak 6      65  126990       qled 4k tv
# 58             ua85cu8000k 8      85  369990        led 4k tv
# 59        magnifiq a32hdx1 3      32   12490  led hd-ready tv
# 60                    e32n 3      32    8399  led hd-ready tv
# 61             ua75cu7700k 7      75  149990        led 4k tv
# 62                  le32a7 3      32   12490  led hd-ready tv
# 63               le32a9000 3      32   15490  led hd-ready tv
# 64            aklt24n-d53w 2      24    7850  led hd-ready tv
# 65             ua55cu7700k 5      55   62490        led 4k tv
# 66        crel065uga024601 6      65   69990       qled 4k tv
# 67             ua65cu8000k 6      65   89490        led 4k tv
# 68             ua55cu8000k 5      55   64290        led 4k tv
# 69        crel024hbb024602 2      24    5190  led hd-ready tv
# 70                 32s5201 3      32   13900   led full hd tv
# 71               ua32t4360 3      32   17623  led hd-ready tv
# 72             ua32t4110ar 3      32   19999  led hd-ready tv
# 73                 a2410ie 2      24    8800  led hd-ready tv
# 74            th-42js650dx 4      42   40849   led full hd tv
# 75             86nano75sqa 8      86  554990        led 4k tv
# 76             55nano75sqa 5      55   64490        led 4k tv
# 77             th-32j200dx 3      32   14561  led hd-ready tv
# 78                32hb250c 3      32   14329  led hd-ready tv
# 79               jsw32nshd 3      32   17990  led hd-ready tv
# 80             lc-32le185m 3      32   24950  led hd-ready tv
#
#                                               Display Resolution Features  \
# 0   32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 1   32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 2   32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 3   65" (165.1 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160     None
# 4   32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 5   32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 6   24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 7   32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 8                43" (109.22 cm), QLED\n4K, 3840x2160  3840x2160     None
# 9   50" (127 cm), LED\n4K, 3840x2160\n50 Hz Refres...  3840x2160     None
# 10  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 11  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 12  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 13  55" (139.7 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160     None
# 14  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 15  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 16  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 17  43" (109.22 cm), LED\nFull HD, 1920x1080\n60 H...  1920x1080     None
# 18  43" (109.22 cm), LED\n4K, 3840x2160\n50 Hz Ref...  3840x2160     None
# 19  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 20  50" (127 cm), LED\n4K, 3840x2160\n50 Hz Refres...  3840x2160     None
# 21  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 22  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 23  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 24            32" (81.28 cm), LED\nHD-Ready, 1366x768   1366x768     None
# 25            32" (81.28 cm), LED\nHD-Ready, 1366x768   1366x768     None
# 26  75" (190.5 cm), LED\n4K, 3840x2160\n120 Hz Ref...  3840x2160     None
# 27  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 28  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 29  75" (190.5 cm), QLED\n4K, 3840x2160\n120 Hz Re...  3840x2160     None
# 30  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 31  24" (60.96 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080     None
# 32  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 33            24" (60.96 cm), LED\nHD-Ready, 1366x768   1366x768     None
# 34  55" (139.7 cm), OLED\n4K, 3840x2160\n120 Hz Re...  3840x2160     None
# 35                43" (109.22 cm), LED\n4K, 3840x2160  3840x2160     None
# 36  43" (109.22 cm), LCD\n4K, 3840x2160\n60 Hz Ref...  3840x2160     None
# 37  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080     None
# 38  32" (81.28 cm), LED\nHD-Ready, 1366x768\n50 Hz...   1366x768     None
# 39  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 40  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 41           43" (109.22 cm), LED\nFull HD, 1920x1080  1920x1080     None
# 42  55" (139.7 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160     None
# 43  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 44  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160     None
# 45  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 46  55" (139.7 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160     None
# 47  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 48           43" (109.22 cm), LED\nFull HD, 1920x1080  1920x1080     None
# 49  43" (109.22 cm), LED\nFull HD, 1920x1080\n60 H...  1920x1080     None
# 50  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 51  43" (109.22 cm), LED\nFull HD, 1920x1080\n60 H...  1920x1080     None
# 52                 65" (165.1 cm), LED\n4K, 3840x2160  3840x2160     None
# 53                55" (139.7 cm), QNED\n4K, 3840x2160  3840x2160     None
# 54  43" (109.22 cm), LED\n4K, 3840x2160\n15 Hz Ref...  3840x2160     None
# 55                 70" (177.8 cm), LED\n4K, 3840x2160  3840x2160     None
# 56  75" (190.5 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160     None
# 57  65" (165.1 cm), QLED\n4K, 3840x2160\n100 Hz Re...  3840x2160     None
# 58  85" (215.9 cm), LED\n4K, 3840x2160\n100 Hz Ref...  3840x2160     None
# 59  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 60  32" (81.28 cm), LED\nHD-Ready, 1366x768\n50 Hz...   1366x768     None
# 61  75" (190.5 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160     None
# 62  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 63  32" (81.28 cm), LED\nHD-Ready, 1366x768\n50 Hz...   1366x768     None
# 64  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 65  55" (139.7 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160     None
# 66                65" (165.1 cm), QLED\n4K, 3840x2160  3840x2160     None
# 67                 65" (165.1 cm), LED\n4K, 3840x2160  3840x2160     None
# 68  55" (139.7 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160     None
# 69  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 70  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080     None
# 71  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 72  32" (81.28 cm), LED\nHD-Ready, 1366x768\n15 Hz...   1366x768     None
# 73  24" (60.96 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 74  42" (106.68 cm), LED\nFull HD, 1920x1080\n60 H...  1920x1080     None
# 75                86" (218.44 cm), LED\n4K, 3840x2160  3840x2160     None
# 76                 55" (139.7 cm), LED\n4K, 3840x2160  3840x2160     None
# 77  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 78  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 79  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768     None
# 80            32" (81.28 cm), LED\nHD-Ready, 1366x768   1366x768     None
#
#                                    Connectivity  \
# 0    2 USB Ports, 2 HDMI Ports, Ethernet, Wi-Fi
# 1   2 USB Ports, 3 HDMI Ports, Wi-Fi, Bluetooth
# 2   2 USB Ports, 3 HDMI Ports, Wi-Fi, Bluetooth
# 3    3 USB Ports, 4 HDMI Ports, Ethernet, Wi-Fi
# 4              2 USB Ports, 2 HDMI Ports, Wi-Fi
# 5                     2 USB Ports, 2 HDMI Ports
# 6                       1 USB Port, 1 HDMI Port
# 7              2 USB Ports, 2 HDMI Ports, Wi-Fi
# 8    2 USB Ports, 3 HDMI Ports, Wi-Fi, Ethernet
# 9    3 USB Ports, 4 HDMI Ports, Wi-Fi, Ethernet
# 10                      1 USB Port, 1 HDMI Port
# 11                    2 USB Ports, 2 HDMI Ports
# 12                      1 USB Port, 1 HDMI Port
# 13   3 USB Ports, 4 HDMI Ports, Ethernet, Wi-Fi
# 14                      1 USB Port, 1 HDMI Port
# 15                     2 USB Ports, 1 HDMI Port
# 16                    2 USB Ports, 2 HDMI Ports
# 17   2 USB Ports, 2 HDMI Ports, Ethernet, Wi-Fi
# 18   2 USB Ports, 3 HDMI Ports, Ethernet, Wi-Fi
# 19                    2 USB Ports, 2 HDMI Ports
# 20  3 HDMI ports, 2 USB ports, Wi-Fi, Bluetooth
# 21                      1 HDMI port, 1 USB port
# 22                    2 HDMI ports, 2 USB ports
# 23                      1 HDMI port, 1 USB port
# 24             2 HDMI ports, 2 USB ports, Wi-Fi
# 25                    2 HDMI ports, 2 USB ports
# 26  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 27                     2 HDMI ports, 1 USB port
# 28                     2 HDMI ports, 1 USB port
# 29  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 30                     2 HDMI ports, 1 USB port
# 31                      1 HDMI port, 1 USB port
# 32                      1 HDMI port, 1 USB port
# 33                      1 HDMI port, 1 USB port
# 34  4 HDMI ports, 2 USB ports, Wi-Fi, Bluetooth
# 35  3 HDMI ports, 2 USB ports, Wi-Fi, Bluetooth
# 36                    3 HDMI ports, 2 USB ports
# 37                    2 HDMI ports, 2 USB ports
# 38                    2 HDMI ports, 2 USB ports
# 39                      1 HDMI port, 1 USB port
# 40                    2 HDMI ports, 2 USB ports
# 41                    2 HDMI ports, 2 USB ports
# 42                    4 HDMI ports, 2 USB ports
# 43                    2 HDMI ports, 2 USB ports
# 44  3 HDMI ports, 2 USB ports, Wi-Fi, Bluetooth
# 45                    2 HDMI ports, 2 USB ports
# 46  3 HDMI ports, 2 USB ports, Wi-Fi, Bluetooth
# 47                    2 HDMI ports, 2 USB ports
# 48                    3 HDMI ports, 2 USB ports
# 49                    3 HDMI ports, 2 USB ports
# 50                    2 HDMI ports, 2 USB ports
# 51             2 HDMI ports, 2 USB ports, Wi-Fi
# 52   3 HDMI ports, 2 USB ports, Wi-Fi, Ethernet
# 53  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 54             3 HDMI ports, 2 USB ports, Wi-Fi
# 55  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 56  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 57  4 HDMI ports, 2 USB ports, Wi-Fi, Bluetooth
# 58  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 59             2 HDMI ports, 2 USB ports, Wi-Fi
# 60                    2 HDMI ports, 2 USB ports
# 61   3 HDMI ports, 2 USB ports, Wi-Fi, Ethernet
# 62                    2 HDMI ports, 2 USB ports
# 63                    2 HDMI ports, 2 USB ports
# 64                      1 HDMI port, 1 USB port
# 65   3 HDMI ports, 2 USB ports, Wi-Fi, Ethernet
# 66  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 67   3 HDMI ports, 2 USB ports, Wi-Fi, Ethernet
# 68   3 HDMI ports, 2 USB ports, Wi-Fi, Ethernet
# 69                    2 HDMI ports, 2 USB ports
# 70                    2 HDMI ports, 2 USB ports
# 71                     2 HDMI ports, 1 USB port
# 72                     2 HDMI ports, 1 USB port
# 73                      1 HDMI port, 1 USB port
# 74                    3 HDMI ports, 2 USB ports
# 75  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 76  4 HDMI ports, 3 USB ports, Wi-Fi, Bluetooth
# 77                    2 HDMI ports, 2 USB ports
# 78                     2 HDMI ports, 1 USB port
# 79                     2 HDMI ports, 1 USB port
# 80                      1 HDMI port, 1 USB port
#
#                                                Design
# 0                                       Colour: Black
# 1                    718 x 420 x 80 mm\nColour: Black
# 2                                        Colour: Grey
# 3                                       Colour: Black
# 4                                       Colour: Black
# 5       73x6.99xN/A mm, Weight: N/A kg, Colour: Black
# 6                                       Colour: Black
# 7   731.7 x 439.2 x 83.0 mm\nWeight: 3.7 kg\nColou...
# 8   965.5 x 559.4 x 25.7 mm\nWeight: 8.1 kg\nColou...
# 9   1118.3 x 644.6 x 25.7 mm\nWeight: 11.2 kg\nCol...
# 10  560 x 335 x 100 mm\nWeight: 3.5 kg\nColour: Black
# 11   735 x 440 x 85 mm\nWeight: 5.9 kg\nColour: Black
# 12                                      Colour: Black
# 13            1232.9 x 709.2 x 25.7 mm\nColour: Other
# 14                   90 x 335 x 550 mm\nColour: Black
# 15                                       Colour: Grey
# 16                  557 x 33.5 x 80 mm\nColour: Black
# 17                  958 x 614 x 200 mm\nColour: Black
# 18   971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black
# 19                   560 x 335 x 90 mm\nColour: Black
# 20  1127 x 662 x 77 mm\nWeight: 9.8 kg\nColour: Black
# 21   552 x 332 x 76 mm\nWeight: 2.1 kg\nColour: Black
# 22                   734 x 434 x 85 mm\nColour: Black
# 23                        Weight: 3 kg\nColour: Black
# 24  731.7 x 439.2 x 83.0 mm\nWeight: 3.7 kg\nColou...
# 25                                      Colour: Black
# 26  1668 x 959 x 59 mm\nWeight: 35.4 kg\nColour: B...
# 27  737.4 x 438 x 74.1 mm\nWeight: 5.5 kg\nColour:...
# 28  737.4 x 438 x 74.1 mm\nWeight: 3.8 kg\nColour:...
# 29              1670 x 957.4 x 26.7 mm\nColour: Other
# 30                   730 x 455 x 85 mm\nColour: Black
# 31  556 x 345.2 x 53.1 mm\nWeight: 3 kg\nColour: B...
# 32                                      Colour: Black
# 33                   550 x 375 x 75 mm\nColour: Black
# 34  1225.4 x 708.6 x 39.9 mm\nWeight: 16.2 kg\nCol...
# 35  977 x 593 x 94.4 mm\nWeight: 9.5 kg\nColour: B...
# 36                                      Colour: Black
# 37                                      Colour: Black
# 38                    90 x 480 x 73 mm\nColour: Black
# 39                                      Colour: Black
# 40                                      Colour: Black
# 41                                      Colour: Black
# 42                                      Colour: Black
# 43                   555 x 335 x 90 mm\nColour: Black
# 44                                      Colour: Black
# 45                                      Colour: Black
# 46                                      Colour: Black
# 47  720 x 480 x 185 mm\nWeight: 3.8 kg\nColour: Black
# 48                                      Colour: Black
# 49                                      Colour: Black
# 50                                      Colour: Black
# 51                                      Colour: Black
# 52                                      Colour: Black
# 53  1236 x 716 x 29.7 mm\nWeight: 14.9 kg\nColour:...
# 54                                      Colour: Black
# 55                      Weight: 27.7 kg\nColour: Grey
# 56  1678 x 964 x 59.9 mm\nWeight: 31.4 kg\nColour:...
# 57  1451.7 x 831.8 x 25.7 mm\nWeight: 21.4 kg\nCol...
# 58  1900 x 1086 x 26.9 mm\nWeight: 41.5 kg\nColour...
# 59                                      Colour: Black
# 60                   732 x 435 x 82 mm\nColour: Black
# 61  1673.2 x 958.2 x 59.9 mm\nWeight: 30.4 kg\nCol...
# 62                                      Colour: Black
# 63                                      Colour: Black
# 64                                      Colour: Black
# 65  1230.5 x 707.2 x 59.9 mm\nWeight: 13.1 kg\nCol...
# 66                  97 x 838 x 1446 mm\nColour: Black
# 67            1450.9 x 831.9 x 25.7 mm\nColour: Other
# 68  1232.1 x 708.8 x 25.7 mm\nWeight: 14.7 kg\nCol...
# 69   557 x 328 x 80 mm\nWeight: 2.6 kg\nColour: Black
# 70                                      Colour: Black
# 71  723.3 x 425.1 x 85.7 mm\nWeight: 3.8 kg\nColou...
# 72                                      Colour: Black
# 73                                      Colour: Black
# 74                   950 x 538 x 88 mm\nColour: Black
# 75  1927 x 1104 x 60 mm\nWeight: 45.2 kg\nColour: ...
# 76  1235 x 774 x 232 mm\nWeight: 14.6 kg\nColour: ...
# 77                                      Colour: Black
# 78                                      Colour: Black
# 79                   730 x 430 x 80 mm\nColour: Black
# 80   749 x 440 x 93 mm\nWeight: 4.9 kg\nColour: Black

# %%
# Query to check for null values in each column after the update
query_null_values_after_update = """
SELECT
    SUM(CASE WHEN Name IS NULL THEN 1 ELSE 0 END) AS Name_nulls,
    SUM(CASE WHEN Brand IS NULL THEN 1 ELSE 0 END) AS Brand_nulls,
    SUM(CASE WHEN Model IS NULL THEN 1 ELSE 0 END) AS Model_nulls,
    SUM(CASE WHEN Inches IS NULL THEN 1 ELSE 0 END) AS Inches_nulls,
    SUM(CASE WHEN Price IS NULL THEN 1 ELSE 0 END) AS Price_nulls,
    SUM(CASE WHEN DisplayType IS NULL THEN 1 ELSE 0 END) AS DisplayType_nulls,
    SUM(CASE WHEN Display IS NULL THEN 1 ELSE 0 END) AS Display_nulls,
    SUM(CASE WHEN Resolution IS NULL THEN 1 ELSE 0 END) AS Resolution_nulls,
    SUM(CASE WHEN Features IS NULL THEN 1 ELSE 0 END) AS Features_nulls,
    SUM(CASE WHEN Connectivity IS NULL THEN 1 ELSE 0 END) AS Connectivity_nulls,
    SUM(CASE WHEN Design IS NULL THEN 1 ELSE 0 END) AS Design_nulls
FROM tv_data;
"""
null_values_after_update = pd.read_sql(query_null_values_after_update, conn)


null_values_after_update
# Out:
#    Name_nulls  Brand_nulls  Model_nulls  Inches_nulls  Price_nulls  \
# 0           0            0            0             0            0
#
#    DisplayType_nulls  Display_nulls  Resolution_nulls  Features_nulls  \
# 0                  0              0                 0              81
#
#    Connectivity_nulls  Design_nulls
# 0                   0             0

# %%
# Step 1: Create a new table without the Features and Connectivity columns
query_create_new_table = """
CREATE TABLE tv_data_new AS
SELECT Name, Brand, Model, Inches, Price, DisplayType, Display, Resolution, Design
FROM tv_data;
"""
conn.execute(query_create_new_table)

# Verify the creation of the new table by listing all columns
query_verify_new_table = "PRAGMA table_info(tv_data_new);"
new_table_columns = conn.execute(query_verify_new_table).fetchall()

# Step 2: Drop the old table
query_drop_old_table = "DROP TABLE tv_data;"
conn.execute(query_drop_old_table)

# Step 3: Rename the new table to the original table name
query_rename_table = "ALTER TABLE tv_data_new RENAME TO tv_data;"
conn.execute(query_rename_table)

# Verify the new table structure
query_verify_final_table = "PRAGMA table_info(tv_data);"
final_table_columns = conn.execute(query_verify_final_table).fetchall()

new_table_columns
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-116-665bce845509> in <cell line: 7>()
#       5 FROM tv_data;
#       6 """
# ----> 7 conn.execute(query_create_new_table)
#       8
#       9 # Verify the creation of the new table by listing all columns
#
# OperationalError: no such column: Name

# %%
final_table_columns
# Out:
# [(0, 'Name', 'TEXT', 0, None, 0),
#  (1, 'Brand', 'TEXT', 0, None, 0),
#  (2, 'Model', 'TEXT', 0, None, 0),
#  (3, 'Inches', 'TEXT', 0, None, 0),
#  (4, 'Price', 'TEXT', 0, None, 0),
#  (5, 'DisplayType', 'TEXT', 0, None, 0),
#  (6, 'Display', 'TEXT', 0, None, 0),
#  (7, 'Resolution', 'TEXT', 0, None, 0),
#  (8, 'Design', 'TEXT', 0, None, 0)]

# %%
# Query to display the PRAGMA table info of the tv_data table
query_pragma = "PRAGMA table_info(tv_data);"
pragma_info = conn.execute(query_pragma).fetchall()

pragma_info
# Out:
# [(0, 'Name', 'TEXT', 0, None, 0),
#  (1, 'Brand', 'TEXT', 0, None, 0),
#  (2, 'Model', 'TEXT', 0, None, 0),
#  (3, 'Inches', 'TEXT', 0, None, 0),
#  (4, 'Price', 'TEXT', 0, None, 0),
#  (5, 'DisplayType', 'TEXT', 0, None, 0),
#  (6, 'Display', 'TEXT', 0, None, 0),
#  (7, 'Resolution', 'TEXT', 0, None, 0),
#  (8, 'Design', 'TEXT', 0, None, 0)]

# %%
# Query to get the PRAGMA table info of the tv_data table
query_pragma = "PRAGMA table_info(tv_data);"
pragma_info = conn.execute(query_pragma).fetchall()

# Convert PRAGMA info to DataFrame
pragma_df = pd.DataFrame(pragma_info, columns=["cid", "name", "type", "notnull", "dflt_value", "pk"])


pragma_df
# Out:
#    cid         name  type  notnull dflt_value  pk
# 0    0         Name  TEXT        0       None   0
# 1    1        Brand  TEXT        0       None   0
# 2    2        Model  TEXT        0       None   0
# 3    3       Inches  TEXT        0       None   0
# 4    4        Price  TEXT        0       None   0
# 5    5  DisplayType  TEXT        0       None   0
# 6    6      Display  TEXT        0       None   0
# 7    7   Resolution  TEXT        0       None   0
# 8    8       Design  TEXT        0       None   0

# %%
# Query to get the first 5 rows of the Design column
query_first_five_design = "SELECT Design FROM tv_data LIMIT 5;"
first_five_design = conn.execute(query_first_five_design).fetchall()

# Query to get the last 5 rows of the Design column
query_last_five_design = "SELECT Design FROM tv_data ORDER BY rowid DESC LIMIT 5;"
last_five_design = conn.execute(query_last_five_design).fetchall()

# Query to get the value counts of the Design column
query_value_counts_design = "SELECT Design, COUNT(*) as count FROM tv_data GROUP BY Design ORDER BY count DESC;"
value_counts_design = conn.execute(query_value_counts_design).fetchall()

first_five_design
# Out:
# [('892 x 512.6 x 85.6 mm\nWeight: 5.1 kg\nColour: Black',),
#  ('715 x 421 x 80 mm\nWeight: 3.44 kg\nColour: Black',),
#  ('715 x 468 x 80 mm\nWeight: 3.55 kg\nColour: Black',),
#  ('1463 x 852 x 87 mm\nWeight: 21.4 kg\nColour: Black',),
#  ('971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black',)]

# %%
last_five_design
# Out:
# [('715.7 x 421.9 x 79.3 mm\nColour: Black',),
#  ('1225.8 x 709.1 x 86.1 mm\nColour: Grey',),
#  ('1456.1 x 840.4 x 54.4 mm\nWeight: 23.2 kg\nColour: Black',),
#  ('1693 x 978 x 88.8 mm\nWeight: 34.6 kg\nColour: Black',),
#  ('732 x 436 x 85 mm\nWeight: 4.1 kg\nColour: Black',)]

# %%
value_counts_design
# Out:
# [('Colour: Black', 201),
#  ('Colour: Grey', 13),
#  ('Colour: Silver', 8),
#  ('967 x 564 x 57.1 mm\nWeight: 8.8 kg\nColour: Black', 7),
#  ('971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black', 5),
#  ('1452.9 x 834 x 60.6 mm\nWeight: 15.9 kg\nColour: Black', 5),
#  ('1235 x 715 x 57.5 mm\nWeight: 14 kg\nColour: Black', 5),
#  ('1121 x 651 x 57.1 mm\nWeight: 11.7 kg\nColour: Black', 5),
#  ('970 x 550 x 100 mm\nColour: Black', 4),
#  ('97.1x57.5x7.7 cm, Weight: 7.8 kg, Colour: Black', 4),
#  ('954 x 540 x 90 mm\nColour: Black', 4),
#  ('1244 x 726 x 87.1 mm\nWeight: 14.3 kg\nColour: Black', 4),
#  ('1228 x 706 x 46.9 mm\nWeight: 18.9 kg\nColour: Black', 4),
#  ('1127 x 662 x 77 mm\nWeight: 9.8 kg\nColour: Black', 4),
#  ('Colour: White', 3),
#  ('970 x 570 x 120 mm\nColour: Black', 3),
#  ('967.5 x 561.4 x 59.7 mm\nWeight: 6.8 kg\nColour: Black', 3),
#  ('965.5 x 559.4 x 25.7 mm\nWeight: 8.1 kg\nColour: Black', 3),
#  ('935 x 440 x 110 mm\nColour: Black', 3),
#  ('925 x 545 x 110 mm\nColour: Black', 3),
#  ('735 x 440 x 110 mm\nColour: Black', 3),
#  ('723.3 x 425.1 x 85.7 mm\nWeight: 3.8 kg\nColour: Black', 3),
#  ('1678 x 964 x 59.9 mm\nWeight: 31.4 kg\nColour: Black', 3),
#  ('1673.2 x 958.2 x 59.9 mm\nWeight: 30.4 kg\nColour: Black', 3),
#  ('1454 x 838 x 57.7 mm\nWeight: 21.5 kg\nColour: Black', 3),
#  ('1454 x 838 x 57.7 mm\nWeight: 21.4 kg\nColour: Black', 3),
#  ('1449.4 x 830.3 x 59.9 mm\nWeight: 20.6 kg\nColour: Other', 3),
#  ('1449.4 x 830.3 x 59.9 mm\nWeight: 20.6 kg\nColour: Black', 3),
#  ('1234.1 x 710.8 x 60.3 mm\nWeight: 10.7 kg\nColour: Black', 3),
#  ('123.2x71.1x6.9 cm, Weight: 14 kg, Colour: Black', 3),
#  ('1071 x 618 x 46.9 mm\nWeight: 14.9 kg\nColour: Black', 3),
#  ('Weight: 6.7 kg\nColour: Black', 2),
#  ('Weight: 3.8 kg\nColour: Black', 2),
#  ('Weight: 13.8 kg\nColour: Black', 2),
#  ('Weight: 11 kg\nColour: Black', 2),
#  ('Colour: Other', 2),
#  ('979.9 x 571.9 x 77.3 mm\nWeight: 8 kg\nColour: Black', 2),
#  ('973 x 572 x 85 mm\nWeight: 8 kg\nColour: Black', 2),
#  ('970 x 570 x 110 mm\nColour: Black', 2),
#  ('966 x 566 x 89 mm\nColour: Black', 2),
#  ('965.5 x 559.8 x 25.7 mm\nWeight: 8.4 kg\nColour: Black', 2),
#  ('964 x 563 x 69 mm\nWeight: 10.1 kg\nColour: Black', 2),
#  ('963.9 x 558.9 x 59.6 mm\nWeight: 8.1 kg\nColour: Other', 2),
#  ('963.9 x 558.9 x 59.6 mm\nWeight: 8.1 kg\nColour: Black', 2),
#  ('963.9 x 558.9 x 59.6 mm\nWeight: 7.7 kg\nColour: Black', 2),
#  ('963.1 x 562.4 x 77.5 mm\nWeight: 7 kg\nColour: Black', 2),
#  ('963.1 x 562.4 x 77.5 mm\nWeight: 6.2 kg\nColour: Black', 2),
#  ('957 x 558 x 80 mm\nColour: Black', 2),
#  ('897 x 525 x 120 mm\nColour: Black', 2),
#  ('739 x 441 x 84 mm\nWeight: 5.1 kg\nColour: Black', 2),
#  ('739 x 441 x 84 mm\nWeight: 4.85 kg\nColour: Black', 2),
#  ('739 x 441 x 84 mm\nColour: Black', 2),
#  ('732 x 435 x 82 mm\nColour: Black', 2),
#  ('731.7 x 439.2 x 83.0 mm\nWeight: 3.7 kg\nColour: Black', 2),
#  ('730 x 437 x 75 mm\nWeight: 4.8 kg\nColour: Black', 2),
#  ('730 x 432 x 88 mm\nWeight: 3.6 kg\nColour: Black', 2),
#  ('718 x 420 x 80 mm\nColour: Black', 2),
#  ('715 x 423.7 x 82.5 mm\nColour: Black', 2),
#  ('71.5x46.8x8 cm, Weight: 3.55 kg, Colour: Black', 2),
#  ('555 x 335 x 90 mm\nColour: Black', 2),
#  ('1677.5 x 962.4 x 61.1 mm\nWeight: 25.3 kg\nColour: Black', 2),
#  ('1676.7 x 960.3 x 26.6 mm\nWeight: 31.4 kg\nColour: Black', 2),
#  ('1676.7 x 959.8 x 26.6 mm\nWeight: 31.4 kg\nColour: Black', 2),
#  ('1675 x 962 x 73 mm\nWeight: 32.2 kg\nColour: Black', 2),
#  ('1675 x 957 x 85 mm\nColour: Black', 2),
#  ('1673.2 x 958.2 x 59.9 mm\nWeight: 30.4 kg\nColour: Other', 2),
#  ('1463 x 852 x 87 mm\nWeight: 21.4 kg\nColour: Black', 2),
#  ('1454 x 838 x 58.4 mm\nWeight: 22.6 kg\nColour: Black', 2),
#  ('1452 x 836 x 72 mm\nWeight: 21.7 kg\nColour: Black', 2),
#  ('1450.9 x 831.8 x 25.7 mm\nWeight: 20.9 kg\nColour: Black', 2),
#  ('1450.9 x 831.4 x 25.7 mm\nWeight: 20.9 kg\nColour: Black', 2),
#  ('1450 x 840 x 98 mm\nWeight: 18.4 kg\nColour: Black', 2),
#  ('1449 x 832 x 45.9 mm\nWeight: 17.1 kg\nColour: Black', 2),
#  ('1449 x 830 x 46.9 mm\nWeight: 24 kg\nColour: Black', 2),
#  ('1446.5 x 829.8 x 54.7 mm\nWeight: 24.1 kg\nColour: Other', 2),
#  ('1444xN/Ax350 mm, Weight: 15.3 kg, Colour: Black', 2),
#  ('1441 x 826 x 45.1 mm\nWeight: 14.8 kg\nColour: Black', 2),
#  ('1243 x 729 x 84 mm\nWeight: 13.9 kg\nColour: Black', 2),
#  ('1243 x 719 x 71 mm\nWeight: 15.7 kg\nColour: Black', 2),
#  ('1240 x 710 x 125 mm\nColour: Black', 2),
#  ('1235 x 715 x 57.5 mm\nWeight: 14.0 kg\nColour: Black', 2),
#  ('1234.1 x 710.8 x 60.3 mm\nWeight: 11.2 kg\nColour: Black', 2),
#  ('1233 x 711 x 74 mm\nWeight: 11.3 kg\nColour: Silver', 2),
#  ('1232.1 x 708.8 x 25.7 mm\nWeight: 14.7 kg\nColour: Other', 2),
#  ('1232.1 x 708.3 x 25.7 mm\nWeight: 14.7 kg\nColour: Other', 2),
#  ('1230.5 x 707.2 x 59.9 mm\nWeight: 13.9 kg\nColour: Other', 2),
#  ('1230.5 x 707.2 x 59.9 mm\nWeight: 13.9 kg\nColour: Black', 2),
#  ('1230.5 x 707.2 x 59.9 mm\nWeight: 13.1 kg\nColour: Black', 2),
#  ('1230 x 718 x 94 mm\nWeight: 10.65 kg\nColour: Black', 2),
#  ('1228 x 708 x 45.9 mm\nWeight: 14.3 kg\nColour: Black', 2),
#  ('1227.6 x 706.7 x 54.7 mm\nWeight: 17.9 kg\nColour: Other', 2),
#  ('1227.4 x 706.2 x 26.9 mm\nWeight: 17.7 kg\nColour: Other', 2),
#  ('1130 x 663 x 86.3 mm\nWeight: 11.3 kg\nColour: Black', 2),
#  ('1130 x 650 x 120 mm\nColour: Black', 2),
#  ('1124.1 x 644.9 x 24.9 mm\nWeight: 11.8 kg\nColour: Black', 2),
#  ('1120.3 x 647 x 60 mm\nWeight: 9.5 kg\nColour: Black', 2),
#  ('1120.3 x 647 x 60 mm\nWeight: 9.1 kg\nColour: Black', 2),
#  ('1120 x 652 x 89 mm\nColour: Black', 2),
#  ('1119 x 649 x 70 mm\nWeight: 12.4 kg\nColour: Black', 2),
#  ('1117 x 646 x 74 mm\nWeight: 9.8 kg\nColour: Silver', 2),
#  ('1116.8 x 644.2 x 59.9 mm\nWeight: 11.4 kg\nColour: Black', 2),
#  ('1070 x 620 x 45.9 mm\nWeight: 11.5 kg\nColour: Black', 2),
#  ('Weight: 9.8 kg\nColour: Black', 1),
#  ('Weight: 9.4 kg\nColour: Black', 1),
#  ('Weight: 9.2 kg\nColour: Black', 1),
#  ('Weight: 8.7 kg\nColour: Black', 1),
#  ('Weight: 8.65 kg\nColour: Black', 1),
#  ('Weight: 7.7 kg\nColour: Black', 1),
#  ('Weight: 6.65 kg\nColour: Black', 1),
#  ('Weight: 6.4 kg\nColour: Black', 1),
#  ('Weight: 6.1 kg\nColour: Black', 1),
#  ('Weight: 5.9 kg\nColour: Black', 1),
#  ('Weight: 5.3 kg\nColour: Black', 1),
#  ('Weight: 4 kg\nColour: Black', 1),
#  ('Weight: 31.1 kg\nColour: Black', 1),
#  ('Weight: 3 kg\nColour: Black', 1),
#  ('Weight: 27.7 kg\nColour: Grey', 1),
#  ('Weight: 21.50 kg\nColour: Black', 1),
#  ('Weight: 21.3 kg\nColour: Black', 1),
#  ('Weight: 20.6 kg\nColour: Black', 1),
#  ('Weight: 18.5 kg\nColour: Black', 1),
#  ('Weight: 18.3 kg\nColour: Black', 1),
#  ('Weight: 18.2 kg\nColour: Black', 1),
#  ('Weight: 17.2 kg\nColour: Black', 1),
#  ('Weight: 16.91 kg\nColour: Black', 1),
#  ('Weight: 12 kg\nColour: Black', 1),
#  ('Weight: 11.6 kg\nColour: Black', 1),
#  ('Weight: 11.4 kg\nColour: Black', 1),
#  ('Weight: 11.1 kg\nColour: Black', 1),
#  ('Colour: Black,Silver,White,Other', 1),
#  ('Colour: Black,Other', 1),
#  ('979.9 x 571.9 x 77.3 mm\nWeight: 8.2 kg\nColour: Black', 1),
#  ('979.9 x 571.9 x 77.3 mm\nWeight: 8.0 kg\nColour: Black', 1),
#  ('977 x 593 x 94.4 mm\nWeight: 9.5 kg\nColour: Black', 1),
#  ('977 x 593 x 26.7 mm\nWeight: 9.5 kg\nColour: Black', 1),
#  ('977 x 577 x 80.8 mm\nWeight: 8.0 kg', 1),
#  ('977 x 575 x 80.8 mm\nWeight: 8.0 kg\nColour: Black', 1),
#  ('977 x 575 x 80.8 mm\nWeight: 8 kg\nColour: Black', 1),
#  ('975 x 572 x 68 mm\nWeight: 7.8 kg\nColour: Black', 1),
#  ('975 x 570 x 120 mm\nWeight: 9.6 kg\nColour: Black', 1),
#  ('973 x 572 x 85 mm\nWeight: 8.0 kg\nColour: Other', 1),
#  ('973 x 572 x 85 mm\nWeight: 8.0 kg\nColour: Black', 1),
#  ('972 x 567 x 70 mm\nWeight: 10 kg\nColour: Black', 1),
#  ('971 x 575 x 77 mm\nColour: Black', 1),
#  ('970.2 x 571.4 x 75 mm\nWeight: 7.7 kg\nColour: Black', 1),
#  ('970 x 620 x 89 mm\nColour: Black', 1),
#  ('970 x 620 x 30 mm\nColour: Black', 1),
#  ('970 x 600 x 80 mm\nWeight: 9.3 kg\nColour: Black', 1),
#  ('970 x 600 x 80 mm\nWeight: 5.9 kg\nColour: Black', 1),
#  ('970 x 600 x 80 mm\nColour: Black', 1),
#  ('970 x 571 x 75 mm\nWeight: 7.7 kg\nColour: Black', 1),
#  ('970 x 570 x 210 mm\nColour: Black', 1),
#  ('970 x 570 x 120 mm\nWeight: 6.6 kg\nColour: Black', 1),
#  ('970 x 570 x 110 mm', 1),
#  ('970 x 566 x 85 mm\nWeight: 6 kg\nColour: Black', 1),
#  ('970 x 565 x 81 mm\nWeight: 7.4 kg\nColour: Black', 1),
#  ('970 x 563 x 85 mm\nWeight: 5.91 kg\nColour: Black', 1),
#  ('97 x 838 x 1446 mm\nColour: Black', 1),
#  ('969.5 x 557.8 x 24.9 mm\nWeight: 8.6 kg\nColour: Black', 1),
#  ('968.0 x 569.8 x 90.0 mm\nWeight: 6.7 kg\nColour: Black', 1),
#  ('968 x 565 x 29.7 mm\nWeight: 9.3 kg\nColour: Black', 1),
#  ('967.5 x 561.4 x 59.7 mm\nWeight: 7.1 kg\nColour: Black', 1),
#  ('967 x 568 x 86 mm\nWeight: 6.75 kg\nColour: Black', 1),
#  ('967 x 565 x 89 mm', 1),
#  ('967 x 564 x 57.7 mm\nWeight: 10.5 kg\nColour: Black', 1),
#  ('967 x 564 x 57.1 mm\nWeight: 10.9 kg\nColour: Other', 1),
#  ('966.7 x 563.1 x 88.5 mm\nWeight: 6.15 kg\nColour: Black', 1),
#  ('966.3 x 560.3 x 25.7 mm\nWeight: 8.1 kg\nColour: Other', 1),
#  ('966.3 x 560.3 x 25.7 mm\nWeight: 8.1 kg\nColour: Black', 1),
#  ('966.3 x 560.2 x 25.7 mm\nWeight: 8.4 kg\nColour: Black', 1),
#  ('966 x 566 x 89 mm\nWeight: 6.90 kg\nColour: Black', 1),
#  ('966 x 566 x 22 mm\nColour: Black', 1),
#  ('965.5 x 559.9 x 257 mm\nWeight: 8.1 kg\nColour: Black', 1),
#  ('965.5 x 559.9 x 25.7 mm\nWeight: 8.1 kg\nColour: Other', 1),
#  ('965.5 x 559.8 x 25.7 mm\nWeight: 8.1 kg\nColour: Other', 1),
#  ('965 x 568 x 81 mm\nWeight: 6.70 kg\nColour: Black', 1),
#  ('965 x 563 x 88.9 mm\nWeight: 6.9 kg\nColour: Black', 1),
#  ('965 x 563 x 88 mm\nWeight: 6.1 kg\nColour: Black', 1),
#  ('965 x 560 x 105 mm\nWeight: 6.7 kg\nColour: Black', 1),
#  ('963.9 x 558.9 x 59.6 mm\nWeight: 7.7 kg\nColour: Other', 1),
#  ('963.3xN/Ax45 mm, Weight: N/A kg, Colour: Black', 1),
#  ('963 x 594 x 81 mm\nWeight: 7.1 kg\nColour: Black', 1),
#  ('963 x 564 x 110 mm\nWeight: 7.4 kg\nColour: Black', 1),
#  ('963 x 560 x 83 mm\nWeight: 7 kg\nColour: Silver', 1),
#  ('963 x 560 x 74 mm\nWeight: 7.4 kg\nColour: Black', 1),
#  ('963 x 560 x 74 mm\nWeight: 7.4 kg', 1),
#  ('962 x 581 x 86 mm\nColour: Black', 1),
#  ('962 x 576 x 75 mm\nWeight: 7.3 kg\nColour: Black', 1),
#  ('962 x 567 x 90 mm\nWeight: 6.65 kg\nColour: Black', 1),
#  ('961 x 560 x 84 mm\nWeight: 6.8 kg\nColour: Black', 1),
#  ('960 x 565 x 87 mm\nWeight: 7 kg\nColour: Silver', 1),
#  ('960 x 562 x 75 mm\nColour: Black', 1),
#  ('960 x 560 x 95 mm\nWeight: 6.7 kg\nColour: Black', 1),
#  ('960 x 560 x 95 mm\nWeight: 6 kg\nColour: Black', 1),
#  ('960 x 560 x 90 mm\nWeight: 6.65 kg\nColour: Black', 1),
#  ('959.8 x 556 x 62 mm\nWeight: 7.1 kg\nColour: Black', 1),
#  ('959.8 x 556 x 62 mm\nColour: Black', 1),
#  ('959.7 x 562.6 x 75.8 mm\nWeight: 10.5 kg\nColour: Black', 1),
#  ('959.3 x 594.6 x 75.7 mm\nWeight: 7 kg\nColour: Black', 1),
#  ('959 x 620 x 556 mm\nWeight: 7.1 kg\nColour: Black', 1),
#  ('959 x 562 x 75.9 mm\nWeight: 6.4 kg\nColour: Black', 1),
#  ('958.2 x 595.2 x 90.5 mm\nWeight: 7 kg\nColour: Black', 1),
#  ('958.2 x 578.6 x 90.5 mm\nWeight: 6.85 kg\nColour: Black', 1),
#  ('958 x 614 x 200 mm\nColour: Black', 1),
#  ('958 x 612 x 226 mm', 1),
#  ('958 x 610 x 256 mm\nWeight: 8 kg\nColour: Black', 1),
#  ('958 x 565 x 88 mm\nWeight: 6.09 kg\nColour: Black', 1),
#  ('957.2 x 558.9 x 84.9 mm\nWeight: 6.64 kg\nColour: Grey', 1),
#  ('957.2 x 558.9 x 84.9 mm\nColour: Black', 1),
#  ('957 x 605 x 220 mm\nWeight: 7.9 kg\nColour: Black', 1),
#  ('957 x 603 x 80 mm\nColour: Grey', 1),
#  ('957 x 559 x 79.2 mm\nWeight: 6.6 kg\nColour: Black', 1),
#  ('957 x 558 x 80 mm\nWeight: 6.7 kg\nColour: Black', 1),
#  ('957 x 558 x 80 mm\nWeight: 6.6 kg\nColour: Grey', 1),
#  ('957 x 210 x 612 mm\nWeight: 5.9 kg\nColour: Black', 1),
#  ('956.8 x 556.1 x 82.4 mm\nColour: Black', 1),
#  ('956 x 559 x 69.5 mm\nWeight: 6.7 kg\nColour: Black', 1),
#  ('955 x 562 x 88 mm\nWeight: 5.96 kg\nColour: Black', 1),
#  ('955 x 558 x 88 mm\nWeight: 5.9 kg\nColour: Black', 1),
#  ('955 x 558 x 87 mm\nWeight: 6.4 kg\nColour: Black', 1),
#  ('955 x 556 x 70 mm\nColour: Black', 1),
#  ('955 x 556 x 30 mm\nColour: Black', 1),
#  ('955 x 556 x 30 mm', 1),
#  ('955 x 555 x 80.5 mm\nColour: Black', 1),
#  ('955 x 555 x 12 mm\nColour: Black', 1),
#  ('950 x 570 x 70 mm\nWeight: 6.1 kg\nColour: Silver', 1),
#  ('950 x 538 x 88 mm\nColour: Black', 1),
#  ('950 x 430 x 60 mm\nWeight: 3.9 kg\nColour: Other', 1),
#  ('932 x 540 x 41.1 mm\nWeight: 9.8 kg\nColour: Black', 1),
#  ('932 x 540 x 41.1 mm\nWeight: 9.0 kg\nColour: Black', 1),
#  ('920 x 540 x 100 mm\nColour: Black', 1),
#  ('910 x 401.8 x 130 mm\nWeight: 6.7 kg\nColour: Black', 1),
#  ('905 x 512 x 658 mm\nWeight: 7 kg\nColour: Black', 1),
#  ('904 x 516 x 85 mm\nWeight: 5.90 kg\nColour: Black', 1),
#  ('900 x 536 x 53 mm\nColour: Black', 1),
#  ('90 x 480 x 73 mm\nColour: Black', 1),
#  ('90 x 335 x 550 mm\nColour: Black', 1),
#  ('893 x 515 x 88 mm\nWeight: 5.16 kg\nColour: Black', 1),
#  ('893 x 508 x 90 mm\nWeight: 5.1 kg\nColour: Black', 1),
#  ('892.3 x 512.8 x 86.5 mm\nWeight: 5.45 kg\nColour: Black', 1),
#  ('892.3 x 512.8 x 86.5 mm\nColour: Black', 1),
#  ('892.2 x 512.8 x 86.5 mm\nWeight: 5.48 kg\nColour: Black', 1),
#  ('892 x 556 x 220 mm\nWeight: 5 kg\nColour: Black', 1),
#  ('892 x 512.6 x 85.6 mm\nWeight: 5.1 kg\nColour: Black', 1),
#  ('85 x 605 x 970 mm\nWeight: 5.9 kg\nColour: Black', 1),
#  ('808 x 490 x 85.2 mm\nWeight: 3.2 kg\nColour: Black', 1),
#  ('753 x 430 x 80 mm\nWeight: 4.35 kg\nColour: Black', 1),
#  ('749 x 440 x 93 mm\nWeight: 4.9 kg\nColour: Black', 1),
#  ('73x6.99xN/A mm, Weight: N/A kg, Colour: Black', 1),
#  ('739 x 44 x 84 mm\nWeight: 5.1 kg\nColour: Black', 1),
#  ('737.4 x 438 x 74.1 mm\nWeight: 5.5 kg\nColour: Black', 1),
#  ('737.4 x 438 x 74.1 mm\nWeight: 4.0 kg\nColour: Black,Other', 1),
#  ('737.4 x 438 x 74.1 mm\nWeight: 4.0 kg\nColour: Black', 1),
#  ('737.4 x 438 x 74.1 mm\nWeight: 4 kg\nColour: Grey', 1),
#  ('737.4 x 438 x 74.1 mm\nWeight: 4 kg\nColour: Black', 1),
#  ('737.4 x 438 x 74.1 mm\nWeight: 3.8 kg\nColour: Black', 1),
#  ('737.3 x 460.6 x 74.0 mm\nWeight: 4.0 kg\nColour: Black', 1),
#  ('737.3 x 460.6 x 74 mm\nWeight: 4.1 kg\nColour: Black', 1),
#  ('736 x 437 x 82.9 mm\nWeight: 5.1 kg\nColour: Black', 1),
#  ('736 x 437 x 82.9 mm\nWeight: 4.65 kg\nColour: Black', 1),
#  ('735 x 440 x 90 mm\nColour: Black', 1),
#  ('735 x 440 x 85 mm\nWeight: 5.9 kg\nColour: Black', 1),
#  ('735 x 440 x 110 mm\nWeight: 5.8 kg\nColour: Black', 1),
#  ('734 x 434 x 85 mm\nColour: Black', 1),
#  ('734 x 425 x 85 mm\nWeight: 3.5 kg\nColour: Black', 1),
#  ('733 x 435 x 80 mm\nWeight: 3.8 kg\nColour: Black', 1),
#  ('732 x 830 x 438 mm\nWeight: 4 kg\nColour: Black', 1),
#  ('732 x 439 x 83 mm\nWeight: 3.7 kg\nColour: Black', 1),
#  ('732 x 436 x 85 mm\nWeight: 4.1 kg\nColour: Black', 1),
#  ('731.7 x 439.2 x 83.0 mm\nWeight: 3.8 kg\nColour: Black', 1),
#  ('731.7 x 439.2 x 83 mm\nWeight: 3.8 kg\nColour: Black', 1),
#  ('731.1 x 439.2 x 83 mm\nWeight: 3.8 kg\nColour: Black', 1),
#  ('731 x 438 x 74 mm\nColour: Black', 1),
#  ('730.1 x 437.4 x 75 mm\nWeight: 4.8 kg\nColour: Black', 1),
#  ('730 x 480 x 195 mm\nColour: Black', 1),
#  ('730 x 455 x 85 mm\nColour: Black', 1),
#  ('730 x 436 x 74 mm\nWeight: 4.5 kg\nColour: Black', 1),
#  ('730 x 432 x 95 mm\nWeight: 3.7 kg\nColour: Black', 1),
#  ('730 x 430 x 80 mm\nColour: Black', 1),
#  ('730 x 430 x 75 mm\nWeight: 3.78 kg', 1),
#  ('730 x 430 x 74 mm\nWeight: 3.9 kg\nColour: Black', 1),
#  ('73.2 x 43.2 x 7.8 mm\nWeight: 3.9 kg\nColour: Black', 1),
#  ('726 x 430 x 83 mm\nWeight: 3.7 kg\nColour: Black', 1),
#  ('725.9 x 427.5 x 73 mm\nWeight: 3.7 kg\nColour: Black', 1),
#  ('723.9 x 440 x 100 mm\nColour: Black', 1),
#  ('723 x 432 x 89 mm\nWeight: 4 kg\nColour: Black', 1),
#  ('722 x 478 x 180 mm', 1),
#  ('722 x 470 x 192 mm\nWeight: 5.7 kg\nColour: Black', 1),
#  ('722 x 430 x 97 mm\nWeight: 3.6 kg\nColour: Black', 1),
#  ('722 x 430 x 87 mm\nWeight: 4 kg\nColour: Silver', 1),
#  ('722 x 428.95 x 82.33 mm\nWeight: 3.86 kg\nColour: Black', 1),
#  ('722 x 427 x 90 mm\nWeight: 4 kg\nColour: Black', 1),
#  ('722 x 427 x 90 mm\nColour: Black', 1),
#  ('722 x 427 x 85 mm\nColour: Black', 1),
#  ('721 x 424 x 78 mm\nWeight: 3.5 kg\nColour: Black', 1),
#  ('721 x 424 x 78 mm\nWeight: 3.4 kg\nColour: Black', 1),
#  ('720.6 x 424 x 77.4 mm\nWeight: 3.54 kg\nColour: Black', 1),
#  ('720.4 x 447.6 x 88.06 mm\nWeight: 3.85 kg\nColour: Black', 1),
#  ('720.1 x 421 x 42 mm\nColour: Black', 1),
#  ('720 x 480 x 185 mm\nWeight: 3.8 kg\nColour: Black', 1),
#  ('720 x 430 x 95 mm\nWeight: 3.75 kg\nColour: Black', 1),
#  ('720 x 430 x 85 mm\nColour: Black', 1),
#  ('720 x 425 x 85.7 mm\nColour: Black', 1),
#  ('720 x 425 x 85 mm\nColour: Black', 1),
#  ('720 x 425 x 78 mm\nColour: Black', 1),
#  ('720 x 420 x 85 mm\nWeight: 6.5 kg\nColour: Black', 1),
#  ('720 x 420 x 80 mm\nWeight: 3.75 kg\nColour: Black', 1),
#  ('720 x 420 x 80 mm\nColour: Black', 1),
#  ('719.4 x 426.8 x 84 mm\nColour: Black', 1),
#  ('718 x 426 x 85 mm\nWeight: 3.5 kg\nColour: Black', 1),
#  ('718 x 423 x 84 mm\nColour: Black', 1),
#  ('718 x 42.6 x 85 mm\nWeight: 3.6 kg\nColour: Black', 1),
#  ('717 x 428 x 86 mm\nWeight: 3.6 kg\nColour: Black', 1),
#  ('716 x 439 x 81 mm\nWeight: 3.97 kg\nColour: Black', 1),
#  ('716 x 424 x 82 mm\nWeight: 3.7 kg\nColour: Black', 1),
#  ('716 x 424 x 82 mm\nWeight: 3.68 kg\nColour: Black', 1),
#  ('715.7 x 470.1 x 184.7 mm\nWeight: 4 kg\nColour: Black', 1),
#  ('715.7 x 421.9 x 79.3 mm\nColour: Black', 1),
#  ('715.7 x 421.3 x 84.5 mm\nWeight: 3.92 kg\nColour: Black', 1),
#  ('715.7 x 190.4 x 82.5 mm\nWeight: 3.9 kg\nColour: Black', 1),
#  ('715.4 x 174.2 x 473.8 mm\nWeight: 3.6 kg\nColour: Black', 1),
#  ('715 x 468 x 80 mm\nWeight: 3.55 kg\nColour: Black', 1),
#  ('715 x 468 x 80 mm\nWeight: 3.54 kg\nColour: Black', 1),
#  ('715 x 423.7 x 82.5 mm\nWeight: 3.9 kg\nColour: Black', 1),
#  ('715 x 421 x 80 mm\nWeight: 3.44 kg\nColour: Black', 1),
#  ('715 x 421 x 42 mm\nWeight: 3.4 kg\nColour: Black', 1),
#  ('715 x 421 x 42 mm\nWeight: 3.4 kg', 1),
#  ('713 x 425 x 65 mm\nWeight: 3.5 kg\nColour: Black', 1),
#  ('711 x 419 x 172 mm\nWeight: 4 kg\nColour: Black', 1),
#  ('70 x 554 x 96 mm\nColour: Black', 1),
#  ('697.5 x 561.4 x 59.7 mm\nWeight: 7.1 kg\nColour: Black', 1),
#  ('69.3 x 953.5 x 1670.3 mm\nWeight: 36.8 kg\nColour: Black', 1),
#  ('67.8x39.3x2.13 in, Weight: 37 kg, Colour: Black', 1),
#  ('645 x 110 x 81 mm\nColour: Black', 1),
#  ('604.5 x 91.9 x 83 mm\nWeight: 6.25 kg\nColour: Black', 1),
#  ('560 x 335 x 90 mm\nColour: Black', 1),
#  ('560 x 335 x 100 mm\nWeight: 3.5 kg\nColour: Black', 1),
#  ('557 x 33.5 x 80 mm\nColour: Black', 1),
#  ('557 x 328 x 80 mm\nWeight: 2.6 kg\nColour: Black', 1),
#  ('556 x 345.2 x 53.1 mm\nWeight: 3 kg\nColour: Black', 1),
#  ('555 x 366 x 165 mm\nColour: Black', 1),
#  ('555 x 335 x 30 mm\nColour: Black', 1),
#  ('552 x 332 x 76 mm\nWeight: 2.1 kg\nColour: Black', 1),
#  ('550 x 375 x 75 mm\nColour: Black', 1),
#  ('530 x 300 x 100 mm\nWeight: 2.4 kg\nColour: Black', 1),
#  ('430 x 430 x 430 mm\nWeight: 3.4 kg\nColour: Black', 1),
#  ('421 x 715 x 80 mm\nWeight: 3.4 kg\nColour: Black', 1),
#  ('389 x 225 x 47 mm\nWeight: 9 kg\nColour: Black', 1),
#  ('350 x 181.1 x 283 mm\nColour: Black', 1),
#  ('2185.1 x 1249.3 x 30.9 mm\nWeight: 61.4 kg\nColour: Black', 1),
#  ('2181.1 x 1244.1 x 63.5 mm\nWeight: 51.8 kg\nColour: Other', 1),
#  ('2180.6 x 1243.9 x 48.4 mm\nWeight: 56.3 kg\nColour: Other', 1),
#  ('2155 x 1225 x 28.2 mm\nWeight: 57 kg\nColour: Black', 1),
#  ('202 x 123 x 189 mm\nWeight: 37.6 kg\nColour: Other', 1),
#  ('198 x 643 x 1100 mm\nWeight: 15 kg\nColour: Black', 1),
#  ('1927 x 1104 x 60 mm\nWeight: 45.2 kg\nColour: Black', 1),
#  ('1927 x 1104 x 59.9 mm\nWeight: 45.2 kg\nColour: Grey', 1),
#  ('1925 x 1105 x 46.1 mm\nWeight: 54.5 kg\nColour: Black', 1),
#  ('1921 x 1107 x 91 mm\nColour: Black', 1),
#  ('1920 x 1105 x 91 mm\nWeight: 44.1 kg\nColour: Black', 1),
#  ('1917 x 1098 x 29.9 mm\nWeight: 54.9 kg\nColour: Black', 1),
#  ('1907 x 1112 x 81 mm\nWeight: 61.7 kg\nColour: Black', 1),
#  ('1901 x 1090 x 73 mm\nWeight: 45.80 kg\nColour: Black', 1),
#  ('1901 x 1090 x 73 mm\nWeight: 44.7 kg\nColour: Black', 1),
#  ('1900.9 x 1086.2 x 26.9 mm\nWeight: 41.5 kg\nColour: Black', 1),
#  ('1900.9 x 1086.1 x 26.9 mm\nWeight: 41.5 kg\nColour: Other', 1),
#  ('1900.9 x 1086 x 26.9 mm\nWeight: 41.5 kg\nColour: Black', 1),
#  ('1900.9 x 1085.7 x 26.9 mm\nWeight: 41.5 kg\nColour: Black', 1),
#  ('1900 x 1086 x 26.9 mm\nWeight: 41.5 kg\nColour: Other', 1),
#  ('19 x 10.8 x 26.9 mm\nWeight: 41.5 kg\nColour: Black', 1),
#  ('1899 x 1094 x 87 mm\nWeight: 42.6 kg\nColour: Black', 1),
#  ('1892.2 x 1081.9 x 27.2 mm\nWeight: 44.5 kg\nColour: Other', 1),
#  ('1892.2 x 1081.9 x 27.2 mm\nWeight: 43.5 kg\nColour: Other', 1),
#  ('1890 x 1089 x 73 mm\nWeight: 37 kg\nColour: Black', 1),
#  ('1890 x 1088 x 95 mm\nWeight: 29 kg\nColour: Black', 1),
#  ('1888 x 1085 x 59 mm\nWeight: 51.8 kg\nColour: Black', 1),
#  ('1876.6 x 1071.5 x 15.4 mm\nWeight: 43.8 kg\nColour: Other', 1),
#  ('1876.6 x 1071.5 x 15.4 mm\nWeight: 43.7 kg\nColour: Other', 1),
#  ('1876.6 x 1071.5 x 15.4 mm\nWeight: 43.1 kg\nColour: Other', 1),
#  ('1851 x 1062 x 55.3 mm\nWeight: 32.3 kg\nColour: Black', 1),
#  ('18.9 x 10.8 x 47 mm\nWeight: 42.5 kg\nColour: Other', 1),
#  ('18.9 x 10.8 x 27.9 mm\nWeight: 43.5 kg\nColour: Other', 1),
#  ('18.7 x 10.6 x 13.3 mm\nWeight: 42.7 kg\nColour: Other', 1),
#  ('1790 x 15.8 x 203 mm\nColour: Black', 1),
#  ('1723 x 992 x 55.3 mm\nWeight: 26.7 kg\nColour: Black', 1),
#  ('1718.5 x 987.6 x 44.9 mm\nWeight: 35.1 kg\nColour: Other', 1),
#  ('1716.6 x 984.1 x 11.2 mm\nWeight: 28.2 kg\nColour: Other', 1),
#  ('1711 x 982 x 47.1 mm\nWeight: 23.5 kg\nColour: Black', 1),
#  ('171 x 987.6 x 44.9 mm\nWeight: 32.4 kg\nColour: Other', 1),
#  ('17.1 x 984.1 x 11.2 mm\nWeight: 28.2 kg\nColour: Other', 1),
#  ('1693 x 978 x 88.8 mm\nWeight: 34.6 kg\nColour: Black', 1),
#  ('1682.3 x 960.4 x 26.9 mm\nWeight: 35.3 kg\nColour: Black', 1),
#  ('1677.5 x 960.2 x 26.6 mm\nWeight: 33.4 kg\nColour: Black', 1),
#  ('1677 x 965 x 30.9 mm\nWeight: 33 kg\nColour: Black', 1),
#  ('1677 x 961 x 85 mm\nWeight: 26 kg\nColour: Black', 1),
#  ('1676.7 x 960.3 x 26.6 mm\nWeight: 32.1 kg\nColour: Black', 1),
#  ('1676.7 x 960.3 x 26.6 mm\nWeight: 31.4 kg\nColour: Other', 1),
#  ('1676 x 990 x 76 mm\nWeight: 37 kg\nColour: Grey', 1),
#  ('1676 x 966 x 87 mm\nWeight: 22.2 kg\nColour: Grey', 1),
#  ('1676 x 964 x 82 mm\nWeight: 22.2 kg\nColour: Black', 1),
#  ('1675 x 964 x 44.5 mm\nWeight: 35.9 kg\nColour: Black', 1),
#  ('1675 x 962 x 73 mm\nWeight: 34.4 kg\nColour: Black', 1),
#  ('1675 x 957 x 85 mm\nWeight: 28.22 kg', 1),
#  ('1673.8 x 964.1 x 57.6 mm\nWeight: 36 kg\nColour: Other', 1),
#  ('1671 x 990 x 958 mm\nWeight: 29 kg\nColour: Black', 1),
#  ('1670.3 x 953.4 x 69.3 mm\nWeight: 38 kg\nColour: Black', 1),
#  ('1670 x 960 x 88 mm\nWeight: 23.50 kg\nColour: Grey', 1),
#  ('1670 x 960 x 88 mm\nColour: Black', 1),
#  ('1670 x 958.2 x 27.7 mm\nWeight: 34.6 kg\nColour: Other', 1),
#  ('1670 x 957.4 x 26.7 mm\nWeight: 35 kg\nColour: Other', 1),
#  ('1670 x 957.4 x 26.7 mm\nColour: Other', 1),
#  ('1668.3 x 955.6 x 17.6 mm\nWeight: 31.9 kg\nColour: Other', 1),
#  ('1668.3 x 955.6 x 17.2 mm\nWeight: 32.2 kg\nColour: Other', 1),
#  ('1668 x 959 x 92 mm\nWeight: 22 kg\nColour: Black', 1),
#  ('1668 x 959 x 91.8 mm\nWeight: 22 kg\nColour: Black', 1),
#  ('1668 x 959 x 59 mm\nWeight: 35.4 kg\nColour: Black', 1),
#  ('1668 x 1025 x 335 mm\nWeight: 29.5 kg\nColour: Black', 1),
#  ('1667 x 959 x 74 mm\nWeight: 18.4 kg', 1),
#  ('1667 x 952.2 x 71.8 mm\nWeight: 29.4 kg\nColour: Black', 1),
#  ('1666 x 958 x 69.5 mm\nWeight: 22.9 kg\nColour: Black', 1),
#  ('1600 x 955 x 185 mm\nWeight: 18.2 kg\nColour: Black', 1),
#  ('16.7 x 959.8 x 26.6 mm\nWeight: 31.4 kg\nColour: Black', 1),
#  ('16.7 x 958.2 x 46.7 mm\nWeight: 33.1 kg\nColour: Other', 1),
#  ('16.7 x 957.4 x 27.7 mm\nWeight: 34.1 kg\nColour: Other', 1),
#  ('16.6 x 955.6 x 17.6 mm\nWeight: 31.9 kg\nColour: Other', 1),
#  ('1577 x 883 x 84 mm\nWeight: 21 kg\nColour: Black', 1),
#  ('1562 x 907 x 59.9 mm\nWeight: 28.4 kg', 1),
#  ('1562 x 907 x 59.9 mm\nWeight: 27.7 kg\nColour: Black', 1),
#  ('1560.6 x 903.6 x 61 mm\nWeight: 22.2 kg\nColour: Black', 1),
#  ('1556.2 x 899.3 x 61.6 mm\nWeight: 24.8 kg\nColour: Black', 1),
#  ('1550 x 910 x 83 mm\nColour: Black', 1),
#  ('1470 x 870 x 30 mm\nColour: Black', 1),
#  ('1470 x 830 x 130 mm\nColour: Other', 1),
#  ('1470 x 830 x 130 mm', 1),
#  ('1470 x 830 x 125 mm\nColour: Black', 1),
#  ('1466 x 930 x 90 mm\nWeight: 13.5 kg\nColour: Other', 1),
#  ('1463 x 850 x 87.8 mm\nWeight: 21.3 kg\nColour: Black', 1),
#  ('1463 x 850 x 87.8 mm\nColour: Other', 1),
#  ('1463 x 845 x 80 mm\nWeight: 20.1 kg\nColour: Black', 1),
#  ('1462 x 842 x 71 mm\nWeight: 21.6 kg\nColour: Black', 1),
#  ('1460 x 844 x 847 mm\nWeight: 17 kg\nColour: Black', 1),
#  ('1456.8 x 831.9 x 24.9 mm\nWeight: 22.4 kg\nColour: Black', 1),
#  ('1456.1 x 840.4 x 54.4 mm\nWeight: 23.2 kg\nColour: Black', 1),
#  ('1456.1 x 836.6 x 59.2 mm\nWeight: 26 kg\nColour: Black', 1),
#  ('1456 x 840 x 29.7 mm\nWeight: 23.6 kg\nColour: Black', 1),
#  ('1456 x 840 x 29.7 mm\nWeight: 22.5 kg\nColour: Grey', 1),
#  ('1454 x 840 x 68.9 mm\nWeight: 27 kg\nColour: Black', 1),
#  ('1454 x 838 x 59 mm\nWeight: 22.6 kg\nColour: Black', 1),
#  ('1454 x 838 x 57.7 mm\nWeight: 27.6 kg\nColour: Other', 1),
#  ('1454 x 838 x 57.7 mm\nWeight: 21.4 kg\nColour: Grey', 1),
#  ('1453.9 x 829.4 x 45.8 mm\nWeight: 25.2 kg\nColour: Black', 1),
#  ('1453 x 860 x 95 mm\nWeight: 17.8 kg\nColour: Grey', 1),
#  ('1452 x 859 x 89 mm\nWeight: 25.1 kg\nColour: Black', 1),
#  ('1452 x 839 x 44.3 mm\nWeight: 24.5 kg\nColour: Black', 1),
#  ('1452 x 834 x 74 mm\nWeight: 16.6 kg\nColour: Black', 1),
#  ('1452 x 834 x 72 mm\nWeight: 22.9 kg\nColour: Black', 1),
#  ('1452 x 834 x 72 mm\nWeight: 22.1 kg\nColour: Silver', 1),
#  ('1452 x 34 x 72 mm\nWeight: 22.9 kg\nColour: Black', 1),
#  ('1451.7 x 832.3 x 25.7 mm\nWeight: 20.9 kg\nColour: Other', 1),
#  ('1451.7 x 832.3 x 25.7 mm\nWeight: 20.9 kg\nColour: Black', 1),
#  ('1451.7 x 831.8 x 25.7 mm\nWeight: 21.4 kg\nColour: Other', 1),
#  ('1451.7 x 831.8 x 25.7 mm\nWeight: 21.4 kg\nColour: Black', 1),
#  ('1451 x 840 x 76 mm\nWeight: 18.6 kg\nColour: Black', 1),
#  ('1451 x 840 x 64 mm\nWeight: 24.1 kg\nColour: Black', 1),
#  ('1451 x 836 x 75 mm\nWeight: 19.10 kg\nColour: Silver', 1),
#  ('1450.9 x 831.9 x 25.7 mm\nWeight: 20.9 kg\nColour: Other', 1),
#  ('1450.9 x 831.9 x 25.7 mm\nWeight: 20.9 kg\nColour: Black', 1),
#  ('1450.9 x 831.9 x 25.7 mm\nColour: Other', 1),
#  ('1450 x 840 x 80 mm\nColour: Black', 1),
#  ('1450 x 838 x 75 mm\nWeight: 20.2 kg\nColour: Black', 1),
#  ('1450 x 833 x 241 mm\nColour: Black', 1),
#  ('1450 x 827 x 79.5 mm\nWeight: 18 kg\nColour: Black', 1),
#  ('1449.6 x 829.3 x 57.6 mm\nWeight: 22.3 kg\nColour: Black', 1),
#  ('1449.5 x 831.2 x 61.9 mm\nWeight: 24.3 kg\nColour: Black', 1),
#  ('1449.4 x 830.3 x 59.9 mm\nColour: Other', 1),
#  ('1449 x 832 x 46.9 mm\nWeight: 24 kg\nColour: Black', 1),
#  ('1449 x 830 x 46.9 mm\nWeight: 25.2 kg\nColour: Black', 1),
#  ('1448 x 838 x 78 mm\nWeight: 18 kg\nColour: Black', 1),
#  ('1448 x 837 x 61 mm\nWeight: 17 kg\nColour: Black', 1),
#  ('1448 x 836 x 53 mm\nWeight: 23 kg\nColour: Black', 1),
#  ('1448 x 834 x 81 mm\nWeight: 17.1 kg\nColour: Black', 1),
#  ('1447.7 x 869.3 x 76.5 mm\nWeight: 18.5 kg\nColour: Black', 1),
#  ('1447 x 836 x 81 mm\nWeight: 18.5 kg\nColour: Black', 1),
#  ('1447 x 832 x 80 mm\nWeight: 18.2 kg\nColour: Black', 1),
#  ('1446.9 x 829.7 x 17.4 mm\nWeight: 22.3 kg\nColour: Other', 1),
#  ('1446.4 x 840.9 x 85 mm\nColour: Grey', 1),
#  ('1446.4 x 829.5 x 87 mm\nColour: Black', 1),
#  ('1446.3 x 829.3 x 26.9 mm\nWeight: 24.4 kg\nColour: Black,Other', 1),
#  ('1446.3 x 829.3 x 26.9 mm\nWeight: 24.2 kg\nColour: Other', 1),
#  ('1446.3 x 828.7 x 26.9 mm\nWeight: 23.7 kg\nColour: Other', 1),
#  ('1446.3 x 828.7 x 25.9 mm\nWeight: 24.4 kg\nColour: Other', 1),
#  ('1446.2 x 825 x 79.5 mm\nWeight: 19.6 kg\nColour: Black', 1),
#  ('1446 x 883 x 76 mm\nWeight: 31.4 kg\nColour: Black', 1),
#  ('1446 x 835 x 86 mm\nWeight: 17.20 kg\nColour: Grey', 1),
#  ('1446 x 834 x 680 mm\nColour: Black', 1),
#  ('1446 x 833 x 81 mm\nWeight: 15.3 kg\nColour: Grey', 1),
#  ('1446 x 833 x 81 mm\nWeight: 15.3 kg\nColour: Black', 1),
#  ('1446 x 833 x 81 mm\nWeight: 10.5 kg\nColour: Black', 1),
#  ('1446 x 833 x 81 mm\nColour: Black', 1),
#  ('1446 x 833 x 73 mm\nWeight: 12.5 kg', 1),
#  ('1446 x 830 x 80 mm\nWeight: 23.90 kg\nColour: Black', 1),
#  ('1446 x 830 x 199 mm\nWeight: 29 kg\nColour: Black', 1),
#  ('1446 x 830 x 19.9 mm\nWeight: 29.0 kg\nColour: Black', 1),
#  ('1446 x 829 x 26 mm\nColour: Black', 1),
#  ('1445.8 x 870.9 x 89.4 mm\nWeight: 17.3 kg\nColour: Black', 1),
#  ('1445 x 900 x 310 mm\nColour: Black', 1),
#  ('1445 x 838 x 98 mm\nWeight: 17.8 kg\nColour: Black', 1),
#  ('1445 x 835 x 100 mm\nWeight: 18.5 kg\nColour: Black', 1),
#  ('1445 x 833 x 81 mm\nWeight: 14 kg\nColour: Black', 1),
#  ('1445 x 831 x 57 mm\nColour: Black', 1),
#  ('1445 x 830 x 98 mm\nWeight: 18.56 kg\nColour: Black', 1),
#  ('1445 x 830 x 98 mm', 1),
#  ('1444.3 x 831.7 x 39.9 mm\nWeight: 21.1 kg\nColour: Other', 1),
#  ('1444.3 x 829.3 x 21.3 mm\nWeight: 23.8 kg\nColour: Other', 1),
#  ('1444.3 x 829.3 x 21.3 mm\nWeight: 23.8 kg\nColour: Black', 1),
#  ('1444 x 837 x 43 mm\nWeight: 27 kg\nColour: Other', 1),
#  ('1444 x 835 x 70 mm\nWeight: 20.2 kg\nColour: Black', 1),
#  ('1444 x 831 x 69.5 mm\nWeight: 15.94 kg\nColour: Black', 1),
#  ('1443.7 x 828.4 x 17.9 mm\nWeight: 22.4 kg\nColour: Other', 1),
#  ('1443.7 x 828.4 x 17.8 mm\nWeight: 22.7 kg\nColour: Other', 1),
#  ('1443.7 x 828.4 x 17.8 mm\nWeight: 22.6 kg\nColour: Black', 1),
#  ('1443.7 x 828.4 x 17.2 mm\nWeight: 22.5 kg\nColour: Other', 1),
#  ('1443.7 x 828.4 x 16.9 mm\nWeight: 23.3 kg\nColour: Other', 1),
#  ('1443.5 x 829.4 x 11 mm\nWeight: 18.9 kg\nColour: Other', 1),
#  ('1442.3 x 827.9 x 105.2 mm\nWeight: 24 kg\nColour: Black', 1),
#  ('1441 x 826 x 45.1 mm\nWeight: 16.6 kg\nColour: Black', 1),
#  ('1441 x 821 x 24.3 mm\nWeight: 22.8 kg\nColour: Black', 1),
#  ('14.5 x 831.4 x 25.7 mm\nWeight: 20.9 kg\nColour: Black', 1),
#  ('14.4 x 829.5 x 46.3 mm\nWeight: 23.1 kg\nColour: Other', 1),
#  ('14.4 x 829.4 x 11 mm\nWeight: 18.9 kg\nColour: Other', 1),
#  ('14.4 x 828.7 x 26.9 mm\nWeight: 24.2 kg\nColour: Other', 1),
#  ('14.4 x 828.4 x 17.2 mm\nWeight: 22.5 kg\nColour: Other', 1),
#  ('1353 x 776.8 x 257 mm\nWeight: 18.6 kg\nColour: Black', 1),
#  ('1303 x 761 x 90.0 mm\nWeight: 18 kg\nColour: Black', 1),
#  ('1291 x 748.6 x 59.9 mm\nWeight: 15.2 kg\nColour: Black', 1),
#  ('128 x 124 x 31.1 mm\nWeight: 61.4 kg\nColour: Other', 1),
#  ('1264 x 780 x 150 mm\nWeight: 11.4 kg\nColour: Black', 1),
#  ('1255.8 x 712 x 80.9 mm\nColour: Black', 1),
#  ('1254.9 x 748.3 x 221 mm\nWeight: 26.5 kg\nColour: White', 1),
#  ('1254.9 x 748.3 x 221 mm\nWeight: 26.5 kg\nColour: Other', 1),
#  ('1247 x 728 x 88.3 mm\nWeight: 13.7 kg\nColour: Black', 1),
#  ('1244 x 726 x 87.1 mm\nWeight: 14.1 kg\nColour: Other', 1),
#  ('1241 x 720 x 63 mm\nWeight: 16.34 kg\nColour: Black', 1),
#  ('1240 x 830 x 90 mm\nWeight: 12.5 kg\nColour: Other', 1),
#  ('1240 x 725 x 120 mm\nWeight: 17.8 kg\nColour: Black', 1),
#  ('1240 x 725 x 120 mm\nWeight: 12.8 kg\nColour: Black', 1),
#  ('1240 x 722 x 78 mm\nWeight: 17 kg\nColour: Black', 1),
#  ('1239.7 x 708.7 x 25.7 mm\nWeight: 15.3 kg\nColour: Black', 1),
#  ('1237.9 x 708.8 x 24.9 mm\nWeight: 16.9 kg\nColour: Black', 1),
#  ('1237.2 x 713.5 x 58.7 mm\nWeight: 18.6 kg\nColour: Black', 1),
#  ('1237 x 816 x 70.5 mm\nWeight: 17.1 kg\nColour: Black', 1),
#  ('1236 x 740 x 97 mm\nWeight: 12.6 kg\nColour: Grey', 1),
#  ('1236 x 718.2 x 89.9 mm\nColour: Black', 1),
#  ('1236 x 718.2 x 22 mm\nColour: Black', 1),
#  ('1236 x 716 x 29.7 mm\nWeight: 15 kg\nColour: Black', 1),
#  ('1236 x 716 x 29.7 mm\nWeight: 14.9 kg\nColour: Grey', 1),
#  ('1235.2 x 715.1 x 54.8 mm\nWeight: 16.9 kg\nColour: Black', 1),
#  ('1235 x 776 x 231 mm\nColour: Black', 1),
#  ('1235 x 774 x 232 mm\nWeight: 14.6 kg\nColour: Black', 1),
#  ('1235 x 715 x 58.1 mm\nWeight: 14.6 kg\nColour: Black', 1),
#  ('1235 x 715 x 58.1 mm\nColour: Black', 1),
#  ('1235 x 715 x 57.5 mm\nWeight: 18.8 kg\nColour: Other', 1),
#  ('1235 x 715 x 57.5 mm\nWeight: 14 kg\nColour: Grey', 1),
#  ('1234.9 x 713.5 x 110 mm\nWeight: 13.06 kg\nColour: Black', 1),
#  ('1234 x 714 x 91 mm\nWeight: 11.14 kg\nColour: Black', 1),
#  ('1234 x 714 x 91 mm\nColour: Black', 1),
#  ('1233 x 781 x 44 mm\nColour: Black', 1),
#  ('1233 x 716 x 44.2 mm\nWeight: 16.3 kg\nColour: Black', 1),
#  ('1233 x 715 x 80 mm\nWeight: 11 kg\nColour: Silver', 1),
#  ('1233 x 713 x 72 mm\nWeight: 15.9 kg\nColour: Black', 1),
#  ('1233 x 711 x 72 mm\nWeight: 17.4 kg\nColour: Black', 1),
#  ('1233 x 711 x 72 mm\nWeight: 17.1 kg\nColour: Black', 1),
#  ('1233 x 711 x 72 mm\nWeight: 16.8 kg\nColour: Black', 1),
#  ('1232.9 x 709.2 x 25.7 mm\nWeight: 14.7 kg\nColour: Black', 1),
#  ('1232.9 x 709.2 x 25.7 mm\nColour: Other', 1),
#  ('1232.1 x 730.6 x 4.9 mm\nWeight: 17.2 kg\nColour: Black', 1),
#  ('1232.1 x 708.8 x 25.7 mm\nWeight: 15.5 kg\nColour: Black', 1),
#  ('1232.1 x 708.8 x 25.7 mm\nWeight: 14.7 kg\nColour: Black', 1),
#  ('1232.1 x 708.3 x 25.7 mm\nWeight: 14.7 kg\nColour: Black', 1),
#  ('1232 x 717 x 76 mm\nWeight: 13 kg\nColour: Silver', 1),
#  ('1232 x 717 x 76 mm\nWeight: 12.5 kg\nColour: Black', 1),
#  ('1232 x 716 x 63.6 mm\nWeight: 17.4 kg\nColour: Black', 1),
#  ('1232 x 716 x 63.6 mm\nWeight: 17.2 kg\nColour: Black', 1),
#  ('1232 x 711 x 76 mm\nColour: Black', 1),
#  ('1232 x 711 x 74 mm\nWeight: 11.3 kg\nColour: Black', 1),
#  ('1231.8 x 709 x 62.5 mm\nWeight: 17.2 kg\nColour: Black', 1),
#  ('1231 x 792.4 x 252.3 mm\nWeight: 11.4 kg\nColour: Black', 1),
#  ('1231 x 713 x 81 mm\nColour: Black', 1),
#  ('1231 x 712.9 x 74.3 mm\nWeight: 11.4 kg\nColour: Black', 1),
#  ('1231 x 710 x 70 mm\nWeight: 16.5 kg\nColour: Black', 1),
#  ('1230.5 x 707.2 x 59.9 mm\nWeight: 13.1 kg\nColour: Other', 1),
#  ('1230.4 x 710 x 71.3 mm\nWeight: 13.94 kg\nColour: Grey', 1),
#  ('1230.1 x 705.9 x 57.4 mm\nWeight: 17.2 kg\nColour: Black', 1),
#  ('1230 x 715 x 90 mm\nWeight: 12.6 kg\nColour: Silver', 1),
#  ('1230 x 715 x 90 mm\nWeight: 11.05 kg\nColour: Black', 1),
#  ('1230 x 715 x 90 mm\nColour: Black', 1),
#  ('1230 x 715 x 80 mm\nWeight: 11 kg\nColour: Black', 1),
#  ('1230 x 715 x 80 mm\nColour: Black', 1),
#  ('1230 x 713 x 70 mm\nWeight: 13.5 kg\nColour: Black', 1),
#  ('1230 x 711 x 81 mm\nColour: Black', 1),
#  ('1230 x 711 x 81 mm', 1),
#  ('1230 x 711 x 78 mm\nWeight: 13.9 kg\nColour: Black', 1),
#  ('1230 x 71.5 x 90 mm\nColour: Black', 1),
#  ('123.2x71.1x6.9 cm, Weight: N/A kg, Colour: Black', 1),
#  ('1228 x 713 x 81 mm\nWeight: 14 kg\nColour: Black', 1),
#  ('1228 x 708 x 46.9 mm\nWeight: 18.9 kg\nColour: Black', 1),
#  ('1228 x 707.3 x 17.4 mm\nWeight: 16.1 kg\nColour: Other', 1),
#  ('1227.8 x 711.2 x 104.1 mm\nColour: Black', 1),
#  ('1227.4 x 705.6 x 26.9 mm\nWeight: 17.2 kg\nColour: Other', 1),
#  ('1227.4 x 705.6 x 25.9 mm\nWeight: 17.7 kg\nColour: Other', 1),
#  ('1227.2 x 704.8 x 46.9 mm\nColour: Black', 1),
#  ('1227 x 750 x 75 mm\nColour: Black', 1),
#  ('1227 x 715 x 76 mm\nWeight: 10.5 kg\nColour: Black,Silver', 1),
#  ('1227 x 715 x 76 mm\nColour: Black', 1),
#  ('1227 x 712 x 53 mm\nWeight: 17.9 kg\nColour: Black', 1),
#  ('1227 x 706 x 26 mm\nColour: Grey', 1),
#  ('1227 x 706 x 26 mm\nColour: Black', 1),
#  ('1227 x 705 x 120 mm\nWeight: 10.1 kg\nColour: Black', 1),
#  ('1226.7 x 747.0 x 92 mm\nWeight: 11.1 kg\nColour: Black', 1),
#  ('1226.4 x 703.4 x 68.2 mm\nWeight: 16.7 kg\nColour: Black', 1),
#  ('1226.4 x 703.2 x 79.3 mm\nWeight: 12.9 kg\nColour: Black', 1),
#  ('1226 x 719 x 84 mm\nWeight: 10.7 kg\nColour: Black', 1),
#  ('1226 x 711 x 81 mm\nWeight: 11 kg\nColour: Grey', 1),
#  ('1226 x 711 x 8.4 mm\nWeight: 10 kg\nColour: Black', 1),
#  ('1226 x 711 x 72 mm\nWeight: 9 kg', 1),
#  ('1226 x 709 x 80 mm\nWeight: 12.1 kg\nColour: Black', 1),
#  ('1226 x 709 x 78 mm\nColour: Black', 1),
#  ('1225.8 x 709.1 x 86.1 mm\nColour: Grey', 1),
#  ('1225.5 x 704.6 x 88.8 mm\nWeight: 17.8 kg\nColour: Black', 1),
#  ('1225.4 x 708.6 x 39.9 mm\nWeight: 16.2 kg\nColour: Other', 1),
#  ('1225 x 880 x 228 mm\nColour: Other', 1),
#  ('1225 x 750 x 240 mm\nWeight: 15 kg\nColour: Black', 1),
#  ('1225 x 720 x 90 mm\nWeight: 16 kg\nColour: Black', 1),
#  ('1225 x 718 x 93 mm\nColour: Black', 1),
#  ('1225 x 717 x 93 mm\nColour: Grey', 1),
#  ('1225 x 707 x 56 mm\nColour: Black', 1),
#  ('1225 x 706 x 23.1 mm\nWeight: 21.8 kg\nColour: Black', 1),
#  ('1224.6 x 706.3 x 11 mm\nWeight: 13.8 kg\nColour: Black', 1),
#  ('1224 x 710 x 70 mm\nWeight: 13 kg\nColour: Black', 1),
#  ('1224 x 708 x 69.5 mm\nWeight: 11 kg\nColour: Black', 1),
#  ('1224 x 708 x 69.5 mm\nWeight: 10.5 kg\nColour: Black', 1),
#  ('1222 x 703 x 45.1 mm\nWeight: 14.1 kg\nColour: Black', 1),
#  ('1222 x 703 x 45.1 mm\nWeight: 12.7 kg\nColour: Black', 1),
#  ('1222 x 703 x 27.2 mm\nWeight: 17.8 kg\nColour: Black', 1),
#  ('1222 x 698 x 27.2 mm\nWeight: 17.1 kg\nColour: Black', 1),
#  ('1200 x 900 x 650 mm\nWeight: 9.4 kg\nColour: Black', 1),
#  ('12.3 x 708.3 x 25.7 mm\nWeight: 14.7 kg\nColour: Black', 1),
#  ('12.2 x 706.4 x 46.1 mm\nWeight: 17.1 kg\nColour: Other', 1),
#  ('12.2 x 706.3 x 11 mm\nWeight: 13.8 kg\nColour: Other', 1),
#  ('12.2 x 705.6 x 26.9 mm\nWeight: 17.7 kg\nColour: Other', 1),
#  ('1130 x 690 x 72 mm\nWeight: 12.5 kg\nColour: Black', 1),
#  ('1130 x 650 x 120 mm\nColour: Other', 1),
#  ('1128.9 x 654.4 x 63.2 mm\nWeight: 12.2 kg\nColour: Black', 1),
#  ('1127 x 662 x 77 mm\nColour: Black', 1),
#  ('1125 x 660 x 120 mm\nColour: Black', 1),
#  ('1120 x 90 x 685 mm\nColour: Black', 1),
#  ('1120 x 652 x 89 mm\nWeight: 9.34 kg\nColour: Black', 1),
#  ('1119.6 x 671.9 x 206.5 mm\nWeight: 20.8 kg\nColour: Other', 1),
#  ('1118.3 x 644.7 x 25.7 mm\nWeight: 11.2 kg\nColour: Other', 1),
#  ('1118.3 x 644.6 x 25.7 mm\nWeight: 11.2 kg\nColour: Other', 1),
#  ('1118.3 x 644.6 x 25.7 mm\nWeight: 10.7 kg\nColour: Black', 1),
#  ('1118.3 x 644.5 x 25.7 mm\nWeight: 11.5 kg\nColour: Black', 1),
#  ('1118.3 x 644.1 x 25.7 mm\nWeight: 11.2 kg\nColour: Black', 1),
#  ('1118.3 x 644.1 x 25.7 mm\nWeight: 10.7 kg\nColour: Black', 1),
#  ('1118 x 676 x 78 mm\nColour: Black', 1),
#  ('1117 x 646 x 74 mm\nWeight: 9.8 kg\nColour: Black', 1),
#  ('1117 x 646 x 74 mm\nWeight: 8.7 kg', 1),
#  ('1116.8 x 644.2 x 59.9 mm\nWeight: 11.4 kg\nColour: Other', 1),
#  ('1116.8 x 644.2 x 59.9 mm\nWeight: 10.9 kg\nColour: Black', 1),
#  ('1116.3 x 653.6 x 71.3 mm\nWeight: 10.1 kg\nColour: Grey', 1),
#  ('1116 x 651 x 81 mm\nWeight: 11.6 kg\nColour: Black', 1),
#  ('1114 x 644 x 27 mm\nColour: Grey', 1),
#  ('1113.6 x 644.1 x 26.9 mm\nWeight: 14 kg\nColour: Other', 1),
#  ('1113 x 680 x 75 mm\nWeight: 9.7 kg\nColour: Black', 1),
#  ('1113 x 654 x 87.2 mm\nColour: Black', 1),
#  ('1113 x 647 x 74 mm\nWeight: 9.0 kg\nColour: Black', 1),
#  ('1112.5 x 681.2 x 92 mm\nWeight: 9.8 kg\nColour: Black', 1),
#  ('1112 x 645 x 81 mm\nWeight: 9.1 kg\nColour: Grey', 1),
#  ('1112 x 645 x 81 mm\nWeight: 8.3 kg\nColour: Black', 1),
#  ('1112 x 645 x 81 mm\nColour: Black', 1),
#  ('1112 x 645 x 30 mm\nColour: Black', 1),
#  ('1112 x 637 x 795 mm\nWeight: 10.37 kg\nColour: Black', 1),
#  ('1111.2 x 644.5 x 86 mm\nColour: Grey', 1),
#  ('1111.2 x 644.5 x 82.6 mm\nColour: Black', 1),
#  ('1111 x 646 x 68.7 mm\nWeight: 8.86 kg\nColour: Black', 1),
#  ('1111 x 644 x 70 mm\nWeight: 7.2 kg', 1),
#  ('1110.8 x 639.5 x 81.8 mm\nWeight: 9 kg\nColour: Black', 1),
#  ('1110 x 650 x 92 mm\nWeight: 8.76 kg\nColour: Grey', 1),
#  ('1110 x 644 x 81 mm\nWeight: 8.3 kg\nColour: Black', 1),
#  ('1110 x 642 x 91 mm\nColour: Black', 1),
#  ('1110 x 603 x 90 mm\nWeight: 9 kg\nColour: Silver', 1),
#  ('111 x 686 x 240 mm\nWeight: 12.5 kg\nColour: Black', 1),
#  ('1106.3 x 653.3 x 262.8 mm\nWeight: 10.1 kg\nColour: Other', 1),
#  ('1102.8 x 637.8 x 59.7 mm\nWeight: 13.2 kg\nColour: Black', 1),
#  ('11.1 x 644.1 x 25.7 mm\nWeight: 11.2 kg\nColour: Black', 1),
#  ('1096 x 640 x 63.6 mm\nWeight: 14.2 kg\nColour: Black', 1),
#  ('1091.6 x 634.6 x 54.9 mm\nWeight: 13.1 kg\nColour: Black', 1)]

# %%
# Add new columns for Weight and Colour
conn.execute("ALTER TABLE tv_data ADD COLUMN Weight TEXT;")
conn.execute("ALTER TABLE tv_data ADD COLUMN Colour TEXT;")

# Update Weight column
conn.execute("""
    UPDATE tv_data
    SET Weight = TRIM(SUBSTR(Design, INSTR(Design, 'Weight: ') + 8, INSTR(Design, ' kg') - INSTR(Design, 'Weight: ') - 8))
""")

# Update Colour column
conn.execute("""
    UPDATE tv_data
    SET Colour = TRIM(SUBSTR(Design, INSTR(Design, 'Colour: ') + 8))
""")

# Verify the updates by fetching the first 5 rows
query_verify_updates = "SELECT Name, Weight, Colour FROM tv_data LIMIT 5;"
updated_rows = conn.execute(query_verify_updates).fetchall()

updated_rows
# Out:
# [('oneplus y1s 40 inch (101 cm) led full hd tv', '5.1', 'Black'),
#  ('tcl 32s5403af 32 inch (81 cm) led full hd tv', '3.44', 'Black'),
#  ('tcl 32s5400a 32 inch (81 cm) led hd-ready tv', '3.55', 'Black'),
#  ('sony bravia kd-65x74l 65 inch (165 cm) led 4k tv', '21.4', 'Black'),
#  ('sony bravia kd-43x74k 43 inch (109 cm) led 4k tv', '7.8', 'Black')]

# %%
# Query to display the PRAGMA table info of the tv_data table
query_pragma = "PRAGMA table_info(tv_data);"
pragma_info = conn.execute(query_pragma).fetchall()

# Convert PRAGMA info to DataFrame
pragma_df = pd.DataFrame(pragma_info, columns=["cid", "name", "type", "notnull", "dflt_value", "pk"])


pragma_df
# Out:
#     cid         name  type  notnull dflt_value  pk
# 0     0         Name  TEXT        0       None   0
# 1     1        Brand  TEXT        0       None   0
# 2     2        Model  TEXT        0       None   0
# 3     3       Inches  TEXT        0       None   0
# 4     4        Price  TEXT        0       None   0
# 5     5  DisplayType  TEXT        0       None   0
# 6     6      Display  TEXT        0       None   0
# 7     7   Resolution  TEXT        0       None   0
# 8     8       Design  TEXT        0       None   0
# 9     9       Weight  TEXT        0       None   0
# 10   10       Colour  TEXT        0       None   0

# %%
# Query to get the first 5 rows of the table
query_first_five = "SELECT * FROM tv_data LIMIT 5;"
first_five_df = pd.read_sql_query(query_first_five, conn)

# Query to get the last 5 rows of the table
query_last_five = "SELECT * FROM tv_data ORDER BY rowid DESC LIMIT 5;"
last_five_df = pd.read_sql_query(query_last_five, conn)

# Query to get 5 random rows of the table
query_random_five = "SELECT * FROM tv_data ORDER BY RANDOM() LIMIT 5;"
random_five_df = pd.read_sql_query(query_random_five, conn)


first_five_df
# Out:
#                                                Name    Brand  \
# 0       oneplus y1s 40 inch (101 cm) led full hd tv  oneplus
# 1      tcl 32s5403af 32 inch (81 cm) led full hd tv      tcl
# 2      tcl 32s5400a 32 inch (81 cm) led hd-ready tv      tcl
# 3  sony bravia kd-65x74l 65 inch (165 cm) led 4k tv     sony
# 4  sony bravia kd-43x74k 43 inch (109 cm) led 4k tv     sony
#
#                 Model Inches  Price      DisplayType  \
# 0               y1s 4     40  18990   led full hd tv
# 1         32s5403af 3     32  13990   led full hd tv
# 2          32s5400a 3     32   9990  led hd-ready tv
# 3  bravia kd-65x74l 6     65  74990        led 4k tv
# 4  bravia kd-43x74k 4     43  39990        led 4k tv
#
#                                              Display Resolution  \
# 0  40" (101.6 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080
# 1  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080
# 2  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768
# 3  65" (165.1 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160
# 4  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
#
#                                               Design Weight Colour
# 0  892 x 512.6 x 85.6 mm\nWeight: 5.1 kg\nColour:...    5.1  Black
# 1  715 x 421 x 80 mm\nWeight: 3.44 kg\nColour: Black   3.44  Black
# 2  715 x 468 x 80 mm\nWeight: 3.55 kg\nColour: Black   3.55  Black
# 3  1463 x 852 x 87 mm\nWeight: 21.4 kg\nColour: B...   21.4  Black
# 4   971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black    7.8  Black

# %%
last_five_df
# Out:
#                                                 Name    Brand          Model  \
# 0  haier le32k8200gt 32 inch (81 cm) led hd-ready tv    haier  le32k8200gt 3
# 1            haier 55p7gt 55 inch (139 cm) led 4k tv    haier       55p7gt 5
# 2     samsung ua65mu6470u 65 inch (165 cm) led 4k tv  samsung  ua65mu6470u 6
# 3          lg 75un8000ptb 75 inch (190 cm) led 4k tv       lg  75un8000ptb 7
# 4    lloyd l32hb250b 32 inch (81 cm) led hd-ready tv    lloyd    l32hb250b 3
#
#   Inches   Price      DisplayType  \
# 0     32   14490  led hd-ready tv
# 1     55   42750        led 4k tv
# 2     65  293900        led 4k tv
# 3     75  119990        led 4k tv
# 4     32   14799  led hd-ready tv
#
#                                              Display Resolution  \
# 0            32" (81.28 cm), LED\nHD-Ready, 1366x768   1366x768
# 1  55" (139.7 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160
# 2                 65" (165.1 cm), LED\n4K, 3840x2160  3840x2160
# 3  75" (190.5 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160
# 4            32" (81.28 cm), LED\nHD-Ready, 1336x768   1336x768
#
#                                               Design   Weight Colour
# 0             715.7 x 421.9 x 79.3 mm\nColour: Black  715.7 x  Black
# 1             1225.8 x 709.1 x 86.1 mm\nColour: Grey   1225.8   Grey
# 2  1456.1 x 840.4 x 54.4 mm\nWeight: 23.2 kg\nCol...     23.2  Black
# 3  1693 x 978 x 88.8 mm\nWeight: 34.6 kg\nColour:...     34.6  Black
# 4   732 x 436 x 85 mm\nWeight: 4.1 kg\nColour: Black      4.1  Black

# %%
random_five_df
# Out:
#                                                 Name     Brand  \
# 0  samsung qa55qn85cak 55 inch (139 cm) neo qled ...   samsung
# 1   motorola 43uhdadmrs3p 43 inch (109 cm) led 4k tv  motorola
# 2          lg 43ut90506lb 43 inch (109 cm) led 4k tv        lg
# 3     samsung qa50q60dau 50 inch (127 cm) qled 4k tv   samsung
# 4             tcl 65p735 65 inch (165 cm) qled 4k tv       tcl
#
#             Model Inches   Price     DisplayType  \
# 0   qa55qn85cak 5     55  159990  neo qled 4k tv
# 1  43uhdadmrs3p 4     43   29999       led 4k tv
# 2   43ut90506lb 4     43   54990       led 4k tv
# 3    qa50q60dau 5     50   64990      qled 4k tv
# 4        65p735 6     65   65990      qled 4k tv
#
#                                              Display Resolution  \
# 0  55" (139.7 cm), Neo QLED\n4K, 3840x2160\n120 H...  3840x2160
# 1  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
# 2  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
# 3  50" (127 cm), QLED\n4K, 3840x2160\n100 Hz Refr...  3840x2160
# 4  65" (165.1 cm), QLED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
#
#                                               Design  Weight Colour
# 0                  1227 x 706 x 26 mm\nColour: Black  1227 x  Black
# 1  959.7 x 562.6 x 75.8 mm\nWeight: 10.5 kg\nColo...    10.5  Black
# 2  968 x 565 x 29.7 mm\nWeight: 9.3 kg\nColour: B...     9.3  Black
# 3  11.1 x 644.1 x 25.7 mm\nWeight: 11.2 kg\nColou...    11.2  Black
# 4   1445 x 833 x 81 mm\nWeight: 14 kg\nColour: Black      14  Black

# %%
# Remove the Weight column from the tv_data table
conn.execute("ALTER TABLE tv_data DROP COLUMN Weight;")

# Verify the table structure to confirm the removal of the Weight column
query_verify_table_structure = "PRAGMA table_info(tv_data);"
table_structure_df = pd.read_sql_query(query_verify_table_structure, conn)


table_structure_df
# Out:
#    cid         name  type  notnull dflt_value  pk
# 0    0         Name  TEXT        0       None   0
# 1    1        Brand  TEXT        0       None   0
# 2    2        Model  TEXT        0       None   0
# 3    3       Inches  TEXT        0       None   0
# 4    4        Price  TEXT        0       None   0
# 5    5  DisplayType  TEXT        0       None   0
# 6    6      Display  TEXT        0       None   0
# 7    7   Resolution  TEXT        0       None   0
# 8    8       Design  TEXT        0       None   0
# 9    9       Colour  TEXT        0       None   0

# %%
# Query to get the first 5 rows of the table
query_first_five = "SELECT * FROM tv_data LIMIT 5;"
first_five_df = pd.read_sql_query(query_first_five, conn)

# Query to get the last 5 rows of the table
query_last_five = "SELECT * FROM tv_data ORDER BY rowid DESC LIMIT 5;"
last_five_df = pd.read_sql_query(query_last_five, conn)

# Query to get 5 random rows of the table
query_random_five = "SELECT * FROM tv_data ORDER BY RANDOM() LIMIT 5;"
random_five_df = pd.read_sql_query(query_random_five, conn)


first_five_df
# Out:
#                                                Name    Brand  \
# 0       oneplus y1s 40 inch (101 cm) led full hd tv  oneplus
# 1      tcl 32s5403af 32 inch (81 cm) led full hd tv      tcl
# 2      tcl 32s5400a 32 inch (81 cm) led hd-ready tv      tcl
# 3  sony bravia kd-65x74l 65 inch (165 cm) led 4k tv     sony
# 4  sony bravia kd-43x74k 43 inch (109 cm) led 4k tv     sony
#
#                 Model Inches  Price      DisplayType  \
# 0               y1s 4     40  18990   led full hd tv
# 1         32s5403af 3     32  13990   led full hd tv
# 2          32s5400a 3     32   9990  led hd-ready tv
# 3  bravia kd-65x74l 6     65  74990        led 4k tv
# 4  bravia kd-43x74k 4     43  39990        led 4k tv
#
#                                              Display Resolution  \
# 0  40" (101.6 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080
# 1  32" (81.28 cm), LED\nFull HD, 1920x1080\n60 Hz...  1920x1080
# 2  32" (81.28 cm), LED\nHD-Ready, 1366x768\n60 Hz...   1366x768
# 3  65" (165.1 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160
# 4  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
#
#                                               Design Colour
# 0  892 x 512.6 x 85.6 mm\nWeight: 5.1 kg\nColour:...  Black
# 1  715 x 421 x 80 mm\nWeight: 3.44 kg\nColour: Black  Black
# 2  715 x 468 x 80 mm\nWeight: 3.55 kg\nColour: Black  Black
# 3  1463 x 852 x 87 mm\nWeight: 21.4 kg\nColour: B...  Black
# 4   971 x 575 x 77 mm\nWeight: 7.8 kg\nColour: Black  Black

# %%
last_five_df
# Out:
#                                                 Name    Brand          Model  \
# 0  haier le32k8200gt 32 inch (81 cm) led hd-ready tv    haier  le32k8200gt 3
# 1            haier 55p7gt 55 inch (139 cm) led 4k tv    haier       55p7gt 5
# 2     samsung ua65mu6470u 65 inch (165 cm) led 4k tv  samsung  ua65mu6470u 6
# 3          lg 75un8000ptb 75 inch (190 cm) led 4k tv       lg  75un8000ptb 7
# 4    lloyd l32hb250b 32 inch (81 cm) led hd-ready tv    lloyd    l32hb250b 3
#
#   Inches   Price      DisplayType  \
# 0     32   14490  led hd-ready tv
# 1     55   42750        led 4k tv
# 2     65  293900        led 4k tv
# 3     75  119990        led 4k tv
# 4     32   14799  led hd-ready tv
#
#                                              Display Resolution  \
# 0            32" (81.28 cm), LED\nHD-Ready, 1366x768   1366x768
# 1  55" (139.7 cm), LED\n4K, 3840x2160\n60 Hz Refr...  3840x2160
# 2                 65" (165.1 cm), LED\n4K, 3840x2160  3840x2160
# 3  75" (190.5 cm), LED\n4K, 3840x2160\n50 Hz Refr...  3840x2160
# 4            32" (81.28 cm), LED\nHD-Ready, 1336x768   1336x768
#
#                                               Design Colour
# 0             715.7 x 421.9 x 79.3 mm\nColour: Black  Black
# 1             1225.8 x 709.1 x 86.1 mm\nColour: Grey   Grey
# 2  1456.1 x 840.4 x 54.4 mm\nWeight: 23.2 kg\nCol...  Black
# 3  1693 x 978 x 88.8 mm\nWeight: 34.6 kg\nColour:...  Black
# 4   732 x 436 x 85 mm\nWeight: 4.1 kg\nColour: Black  Black

# %%
random_five_df
# Out:
#                                                 Name    Brand  \
# 0     samsung ua43du7660k 43 inch (109 cm) led 4k tv  samsung
# 1           hisense 43a6k 43 inch (109 cm) led 4k tv  hisense
# 2    innoq 43e-delux 43 inch (109 cm) led full hd tv    innoq
# 3  sony bravia xr-65a95k 65 inch (165 cm) oled 4k tv     sony
# 4  croma crel043foa024601 43 inch (109 cm) led fu...    croma
#
#                 Model Inches   Price     DisplayType  \
# 0       ua43du7660k 4     43   38990       led 4k tv
# 1             43a6k 4     43   27999       led 4k tv
# 2         43e-delux 4     43   14990  led full hd tv
# 3  bravia xr-65a95k 6     65  309990      oled 4k tv
# 4  crel043foa024601 4     43   23990  led full hd tv
#
#                                              Display Resolution  \
# 0  43" (109.22 cm), LED\n4K, 3840x2160\n50 Hz Ref...  3840x2160
# 1  43" (109.22 cm), LED\n4K, 3840x2160\n60 Hz Ref...  3840x2160
# 2  43" (109.22 cm), LED\nFull HD, 1920x1080\n60 H...  1920x1080
# 3  65" (165.1 cm), OLED\n4K, 3840x2160\n120 Hz Re...  3840x2160
# 4  43" (109.22 cm), LED\nFull HD, 1920x1080\n60 H...  1920x1080
#
#                                               Design Colour
# 0  697.5 x 561.4 x 59.7 mm\nWeight: 7.1 kg\nColou...  Black
# 1                                      Colour: Black  Black
# 2                                      Colour: Black  Black
# 3   1444 x 837 x 43 mm\nWeight: 27 kg\nColour: Other  Other
# 4  957 x 605 x 220 mm\nWeight: 7.9 kg\nColour: Black  Black

# %%
# Create a new table without the Display and Design columns
query_create_new_table = """
CREATE TABLE tv_data_new AS
SELECT Name, Brand, Model, Inches, Price, DisplayType, Resolution, Colour
FROM tv_data;
"""
conn.execute(query_create_new_table)

# Drop the old table
conn.execute("DROP TABLE tv_data;")

# Rename the new table to the original table name
conn.execute("ALTER TABLE tv_data_new RENAME TO tv_data;")

# Verify the new table structure
query_verify_table_structure = "PRAGMA table_info(tv_data);"
table_structure_df = pd.read_sql_query(query_verify_table_structure, conn)

table_structure_df
# Out:
#    cid         name  type  notnull dflt_value  pk
# 0    0         Name  TEXT        0       None   0
# 1    1        Brand  TEXT        0       None   0
# 2    2        Model  TEXT        0       None   0
# 3    3       Inches  TEXT        0       None   0
# 4    4        Price  TEXT        0       None   0
# 5    5  DisplayType  TEXT        0       None   0
# 6    6   Resolution  TEXT        0       None   0
# 7    7       Colour  TEXT        0       None   0

# %%
# Export the updated table to a CSV file
updated_df = pd.read_sql_query("SELECT * FROM tv_data;", conn)
output_file_path = "updated_data_tv.csv"
updated_df.to_csv(output_file_path, index=False)

output_file_path
# Out:
# 'updated_data_tv.csv'

# %%
# Query to count the number of rows in the dataset
cursor.execute('SELECT COUNT(*) FROM tv_data')
num_rows = cursor.fetchone()[0]
num_rows
# Out:
# 1061

# %%
# Display the first 5 rows of the DisplayType column
first_5_displaytype = cursor.execute('SELECT DisplayType FROM tv_data LIMIT 5').fetchall()

# Display the last 5 rows of the DisplayType column
last_5_displaytype = cursor.execute('SELECT DisplayType FROM tv_data ORDER BY ROWID DESC LIMIT 5').fetchall()

# Count the occurrences of each unique value in the DisplayType column
displaytype_value_counts = cursor.execute('SELECT DisplayType, COUNT(*) FROM tv_data GROUP BY DisplayType').fetchall()

first_5_displaytype
# Out:
# [('led full hd tv',),
#  ('led full hd tv',),
#  ('led hd-ready tv',),
#  ('led 4k tv',),
#  ('led 4k tv',)]

# %%
last_5_displaytype
# Out:
# [('led hd-ready tv',),
#  ('led 4k tv',),
#  ('led 4k tv',),
#  ('led 4k tv',),
#  ('led hd-ready tv',)]

# %%
displaytype_value_counts
# Out:
# [('32 inch (81 cm) led hd-ready tv', 1),
#  ('43 inch (109 cm) led 4k tv', 1),
#  ('50 inch (127 cm) led 4k tv', 1),
#  ('55 inch (139 cm) led 4k tv', 1),
#  ('65 inch (165 cm) led 4k tv', 1),
#  ('lcd 4k tv', 1),
#  ('led 4k tv', 481),
#  ('led 8k uhd tv', 2),
#  ('led full hd tv', 117),
#  ('led hd-ready tv', 186),
#  ('mini led 4k tv', 7),
#  ('neo qled 4k tv', 26),
#  ('neo qled 8k uhd tv', 11),
#  ('oled 4k tv', 45),
#  ('oled evo 4k tv', 15),
#  ('qd-mini led 4k tv', 4),
#  ('qled 4k tv', 148),
#  ('qled 8k uhd tv', 3),
#  ('qled full hd tv', 1),
#  ('qled hd-ready tv', 2),
#  ('qned 4k tv', 6),
#  ('qned 8k uhd tv', 1)]

# %%
# SQL query to remove unnecessary information from DisplayType
cursor.execute('''
UPDATE tv_data
SET DisplayType = TRIM(REPLACE(DisplayType, substr(DisplayType, 1, instr(DisplayType, 'inch') + 4), ''))
''')
conn.commit()

# Verify the update by displaying the first few rows of the DisplayType column
cursor.execute('SELECT DisplayType FROM tv_data LIMIT 5')
updated_first_5_displaytype = cursor.fetchall()

updated_first_5_displaytype
# Out:
# [('full hd tv',), ('full hd tv',), ('hd-ready tv',), ('4k tv',), ('4k tv',)]

# %%
# SQL query to convert DisplayType values to title case
cursor.execute('''
UPDATE tv_data
SET DisplayType = UPPER(SUBSTR(DisplayType, 1, 1)) || LOWER(SUBSTR(DisplayType, 2, LENGTH(DisplayType) - 1))
''')
conn.commit()

# Verify the update by displaying the first few rows of the DisplayType column
cursor.execute('SELECT DisplayType FROM tv_data LIMIT 5')
title_case_first_5_displaytype = cursor.fetchall()

title_case_first_5_displaytype
# Out:
# [('Full hd tv',), ('Full hd tv',), ('Hd-ready tv',), ('4k tv',), ('4k tv',)]

# %%
# Query to fetch all distinct values from the DisplayType column
distinct_values = cursor.execute('SELECT DISTINCT DisplayType FROM tv_data').fetchall()
distinct_values
# Out:
# [('Full hd tv',),
#  ('Hd-ready tv',),
#  ('4k tv',),
#  ('(127 cm) led 4k tv',),
#  ('(109 cm) led 4k tv',),
#  ('Evo 4k tv',),
#  ('Qled 4k tv',),
#  ('Qled 8k uhd tv',),
#  ('(165 cm) led 4k tv',),
#  ('(139 cm) led 4k tv',),
#  ('Led 4k tv',),
#  ('Ini led 4k tv',),
#  ('8k uhd tv',),
#  ('(81 cm) led hd-ready tv',)]

# %%
# SQL query to remove size information and strip text in the DisplayType column
cursor.execute('''
UPDATE tv_data
SET DisplayType = TRIM(REPLACE(DisplayType, substr(DisplayType, instr(DisplayType, 'cm)') - 5, 9), ''))
WHERE DisplayType LIKE '%cm)%'
''')
conn.commit()

# Verify the update by fetching the distinct values from the DisplayType column again
distinct_values_after_removal = cursor.execute('SELECT DISTINCT DisplayType FROM tv_data').fetchall()
distinct_values_after_removal
# Out:
# [('Full hd tv',),
#  ('Hd-ready tv',),
#  ('4k tv',),
#  ('led 4k tv',),
#  ('Evo 4k tv',),
#  ('Qled 4k tv',),
#  ('Qled 8k uhd tv',),
#  ('Led 4k tv',),
#  ('Ini led 4k tv',),
#  ('8k uhd tv',),
#  ('led hd-ready tv',)]

# %%
# SQL query to standardize terms in the DisplayType column
cursor.execute('''
UPDATE tv_data
SET DisplayType = CASE
    WHEN DisplayType = 'Full hd tv' THEN 'Full HD TV'
    WHEN DisplayType = 'Hd-ready tv' THEN 'HD-Ready TV'
    WHEN DisplayType = '4k tv' THEN '4K TV'
    WHEN DisplayType = 'led 4k tv' THEN 'LED 4K TV'
    WHEN DisplayType = 'Evo 4k tv' THEN 'EVO 4K TV'
    WHEN DisplayType = 'Qled 4k tv' THEN 'QLED 4K TV'
    WHEN DisplayType = 'Qled 8k uhd tv' THEN 'QLED 8K UHD TV'
    WHEN DisplayType = 'Ini led 4k tv' THEN 'Mini LED 4K TV'
    WHEN DisplayType = '8k uhd tv' THEN '8K UHD TV'
    WHEN DisplayType = 'led hd-ready tv' THEN 'LED HD-Ready TV'
    ELSE DisplayType
END
''')
conn.commit()

# Verify the update by fetching the distinct values from the DisplayType column again
standardized_distinct_values = cursor.execute('SELECT DISTINCT DisplayType FROM tv_data').fetchall()
standardized_distinct_values
# Out:
# [('Full HD TV',),
#  ('HD-Ready TV',),
#  ('4K TV',),
#  ('LED 4K TV',),
#  ('EVO 4K TV',),
#  ('QLED 4K TV',),
#  ('QLED 8K UHD TV',),
#  ('Led 4k tv',),
#  ('Mini LED 4K TV',),
#  ('8K UHD TV',),
#  ('LED HD-Ready TV',)]

# %%
# SQL query to correct remaining inconsistencies
cursor.execute('''
UPDATE tv_data
SET DisplayType = 'LED 4K TV'
WHERE DisplayType = 'Led 4k tv';
''')
conn.commit()

# Verify the update by fetching the distinct values from the DisplayType column again
final_distinct_values = cursor.execute('SELECT DISTINCT DisplayType FROM tv_data').fetchall()
final_distinct_values
# Out:
# [('Full HD TV',),
#  ('HD-Ready TV',),
#  ('4K TV',),
#  ('LED 4K TV',),
#  ('EVO 4K TV',),
#  ('QLED 4K TV',),
#  ('QLED 8K UHD TV',),
#  ('Mini LED 4K TV',),
#  ('8K UHD TV',),
#  ('LED HD-Ready TV',)]

# %%
# Query to get the value counts of the DisplayType column after standardization
cursor.execute('SELECT DisplayType, COUNT(*) FROM tv_data GROUP BY DisplayType ORDER BY COUNT(*) DESC')
displaytype_value_counts_final = cursor.fetchall()

displaytype_value_counts_final
# Out:
# [('4K TV', 681),
#  ('HD-Ready TV', 188),
#  ('Full HD TV', 118),
#  ('QLED 4K TV', 26),
#  ('EVO 4K TV', 15),
#  ('QLED 8K UHD TV', 11),
#  ('LED 4K TV', 11),
#  ('8K UHD TV', 6),
#  ('Mini LED 4K TV', 4),
#  ('LED HD-Ready TV', 1)]

# %%
# SQL query to remove "TV" from the DisplayType column
cursor.execute('''
UPDATE tv_data
SET DisplayType = REPLACE(DisplayType, ' TV', '')
''')
conn.commit()

# Verify the update by fetching the distinct values from the DisplayType column again
distinct_values_no_tv = cursor.execute('SELECT DISTINCT DisplayType FROM tv_data').fetchall()
distinct_values_no_tv
# Out:
# [('Full HD',),
#  ('HD-Ready',),
#  ('4K',),
#  ('LED 4K',),
#  ('EVO 4K',),
#  ('QLED 4K',),
#  ('QLED 8K UHD',),
#  ('Mini LED 4K',),
#  ('8K UHD',),
#  ('LED HD-Ready',)]

# %%
# Query to get the final value counts of the DisplayType column after removing "TV"
cursor.execute('SELECT DisplayType, COUNT(*) FROM tv_data GROUP BY DisplayType ORDER BY COUNT(*) DESC')
final_value_counts_no_tv = cursor.fetchall()

final_value_counts_no_tv
# Out:
# [('4K', 681),
#  ('HD-Ready', 188),
#  ('Full HD', 118),
#  ('QLED 4K', 26),
#  ('EVO 4K', 15),
#  ('QLED 8K UHD', 11),
#  ('LED 4K', 11),
#  ('8K UHD', 6),
#  ('Mini LED 4K', 4),
#  ('LED HD-Ready', 1)]

# %%
# Query to fetch the first 5 rows of the dataset
cursor.execute('SELECT * FROM tv_data LIMIT 5')
first_5_rows = cursor.fetchall()

# Convert the result to a DataFrame for better visualization
columns = [description[0] for description in cursor.description]
first_5_rows_df = pd.DataFrame(first_5_rows, columns=columns)


first_5_rows_df
# Out:
#                                                Name    Brand  \
# 0       oneplus y1s 40 inch (101 cm) led full hd tv  oneplus
# 1      tcl 32s5403af 32 inch (81 cm) led full hd tv      tcl
# 2      tcl 32s5400a 32 inch (81 cm) led hd-ready tv      tcl
# 3  sony bravia kd-65x74l 65 inch (165 cm) led 4k tv     sony
# 4  sony bravia kd-43x74k 43 inch (109 cm) led 4k tv     sony
#
#                 Model Inches  Price DisplayType Resolution Colour
# 0               y1s 4     40  18990     Full HD  1920x1080  Black
# 1         32s5403af 3     32  13990     Full HD  1920x1080  Black
# 2          32s5400a 3     32   9990    HD-Ready   1366x768  Black
# 3  bravia kd-65x74l 6     65  74990          4K  3840x2160  Black
# 4  bravia kd-43x74k 4     43  39990          4K  3840x2160  Black
